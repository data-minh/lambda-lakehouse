# %% [markdown]
# ## Dữ liệu Streaming

# %%
# pip install kafka-python websocket-client python-dotenv
import os
import json
import time
from datetime import datetime, timezone

from dotenv import load_dotenv
import websocket

from kafka import KafkaProducer
from kafka.admin import KafkaAdminClient, NewTopic
from kafka.errors import TopicAlreadyExistsError, NoBrokersAvailable

# ====== ENV & cấu hình ======
load_dotenv()

TOKEN = os.getenv("FINNHUB_API_TOKEN")
if not TOKEN:
    raise RuntimeError("Thiếu FINNHUB_API_TOKEN trong .env")

# Kết nối WS Finnhub
WS_URL = f"wss://ws.finnhub.io?token={TOKEN}"

# Kafka
KAFKA_BOOTSTRAP = os.getenv("KAFKA_BOOTSTRAP", "localhost:9092")  # host: dùng localhost:9092
KAFKA_TOPIC     = os.getenv("KAFKA_TOPIC", "crypto.trades")       # tên topic
KAFKA_PARTITIONS = int(os.getenv("KAFKA_PARTITIONS", "6"))
KAFKA_RF         = int(os.getenv("KAFKA_RF", "1"))                # 1 cho cluster đơn node

# WS keepalive
PING_INTERVAL = 15
PING_TIMEOUT  = 10
SUB_DELAY     = 0.5  # nương tay khi subscribe

SYMBOLS = [
    "BINANCE:BTCUSDT",
    "BINANCE:ETHUSDT",
    "BINANCE:BNBUSDT",
]

# ====== Kafka utils ======
def ensure_topic(bootstrap: str, topic: str, partitions: int = 6, rf: int = 1, configs: dict | None = None):
    """
    Kiểm tra topic; nếu chưa có thì tạo mới.
    Trả về True nếu OK, raise nếu không kết nối được broker.
    """
    admin = None
    try:
        admin = KafkaAdminClient(bootstrap_servers=bootstrap, client_id="topic-manager")
        # Kiểm tra tồn tại
        existing = admin.list_topics()
        if topic in existing:
            return True
        # Tạo mới
        nt = NewTopic(name=topic, num_partitions=partitions, replication_factor=rf, topic_configs=configs or {})
        admin.create_topics([nt], validate_only=False)
        return True
    except TopicAlreadyExistsError:
        return True
    except NoBrokersAvailable as e:
        raise RuntimeError(f"Không kết nối được Kafka tại {bootstrap}: {e}") from e
    finally:
        if admin:
            admin.close()

def build_producer(bootstrap: str) -> KafkaProducer:
    """
    Tạo KafkaProducer với cấu hình hợp lý cho stream trade.
    """
    return KafkaProducer(
        bootstrap_servers=bootstrap,
        acks="all",                 # an toàn hơn (leader + ISR)
        linger_ms=50,               # gộp lô nhẹ
        batch_size=64 * 1024,       # 64KB
        retries=5,
        value_serializer=lambda v: json.dumps(v, ensure_ascii=False).encode("utf-8"),
        key_serializer=lambda k: k.encode("utf-8") if k else None,
    )

# ====== Helpers thời gian ======
def now_utc():
    return datetime.now(timezone.utc)

def epoch_ms(dt: datetime) -> int:
    return int(dt.timestamp() * 1000)

# ====== Kafka producer (global) ======
producer: KafkaProducer | None = None

def send_to_kafka(rec: dict):
    """
    Produce 1 record vào Kafka (key = symbol, value = JSON).
    Dùng trade_ts (nếu có) làm timestamp của message.
    """
    global producer
    if producer is None:
        return
    try:
        key = rec.get("symbol")
        ts_ms = rec.get("trade_ts") or rec.get("recv_ts")
        # Gửi, không flush mỗi bản ghi (flush khi shutdown)
        producer.send(KAFKA_TOPIC, key=key, value=rec, timestamp_ms=int(ts_ms) if ts_ms else None)
    except Exception as e:
        print("Kafka produce error:", e)

def close_kafka():
    global producer
    if producer:
        try:
            producer.flush(timeout=5)
            producer.close(timeout=5)
        except Exception:
            pass
        producer = None

# ====== WS callbacks ======
def on_message(ws, message):
    recv_dt = now_utc()
    recv_ms = epoch_ms(recv_dt)

    try:
        msg = json.loads(message)
    except Exception:
        return

    if not isinstance(msg, dict) or msg.get("type") != "trade":
        return

    data = msg.get("data") or []
    for d in data:
        symbol = d.get("s")
        price  = d.get("p")
        volume = d.get("v")
        trade_ts = d.get("t")  # epoch ms
        cond   = d.get("c")

        # Fallback timestamp nếu thiếu t
        trade_ms = trade_ts if isinstance(trade_ts, int) else recv_ms
        trade_dt = datetime.fromtimestamp(trade_ms / 1000, tz=timezone.utc)

        rec = {
            "source": "finnhub",
            "type": "trade",
            "symbol": symbol,
            "price": price,
            "volume": volume,
            "trade_ts": trade_ms,
            "recv_ts": recv_ms,
            "conditions": cond,
            "trade_time_iso": trade_dt.strftime("%Y-%m-%dT%H:%M:%S.%f")[:-3] + "Z",
        }

        # ĐẨY VÀO KAFKA
        send_to_kafka(rec)

def on_error(ws, error):
    print("WS error:", error)

def on_close(ws, code, msg):
    print("WS closed", code, msg)

def on_open(ws):
    # Đăng ký 10 symbol, “nương tay” để tránh throttle
    for sym in SYMBOLS:
        ws.send(json.dumps({"type": "subscribe", "symbol": sym}))
        time.sleep(SUB_DELAY)
    print(f"Subscribed {len(SYMBOLS)} symbols.")

# ====== Main loop ======
def run():
    # 1) Đảm bảo topic tồn tại
    ensure_topic(KAFKA_BOOTSTRAP, KAFKA_TOPIC, partitions=KAFKA_PARTITIONS, rf=KAFKA_RF)

    # 2) Tạo producer
    global producer
    producer = build_producer(KAFKA_BOOTSTRAP)

    # 3) Giữ kết nối WS + reconnect with backoff
    backoff = 1
    while True:
        try:
            ws = websocket.WebSocketApp(
                WS_URL,
                on_open=on_open,
                on_message=on_message,
                on_error=on_error,
                on_close=on_close,
            )
            ws.run_forever(ping_interval=PING_INTERVAL, ping_timeout=PING_TIMEOUT)
        except KeyboardInterrupt:
            print("Stopping by user...")
            break
        except Exception as e:
            print("WS exception:", e)

        # Backoff khi đứt kết nối
        time.sleep(backoff)
        backoff = min(backoff * 2, 60)

    # 4) Đóng Kafka producer gọn
    close_kafka()

if __name__ == "__main__":
    run()
# Out:
# Subscribed 3 symbols.

# %% [markdown]
# ## Dữ liệu Batch

# %%
from vnstock import Listing
listing = Listing()

vnstock_list = listing.all_symbols()['symbol'].to_list()

# %%
import pandas as pd
from vnstock import Quote, Listing
from datetime import datetime, timezone, timedelta
import time # Thêm thư viện time để tạm dừng

# --- Cài đặt thời gian ---
vn_tz = timezone(timedelta(hours=7))
now_vn = datetime.now(vn_tz)
today_str = now_vn.strftime("%Y-%m-%d")
START_DATE = '2025-01-01'
RESOLUTION = '1D' # BẮT BUỘC dùng '1D' cho lịch sử dài hạn
DELAY_SECONDS = 0.5 # Thêm độ trễ để tránh bị khóa IP

# --- Bước 1: Khởi tạo Listing và lấy danh sách mã ---
try:
    listing_obj = Listing() # Sửa lỗi 1: Khởi tạo đối tượng
    df_symbols = listing_obj.all_symbols()
    vnstock_list = df_symbols['symbol'].to_list()
    print(f"Tìm thấy {len(vnstock_list)} mã. Bắt đầu tải...")
except Exception as e:
    print(f"Không thể lấy danh sách mã: {e}")
    vnstock_list = [] # Gán list rỗng để code không chạy tiếp

# --- Bước 2: Chuẩn bị list để thu thập ---
list_of_dfs = []
symbol_no_data = [] # Danh sách các mã không tải được hoặc không có dữ liệu

# --- Bước 3: Vòng lặp ---
for i, symbol in enumerate(vnstock_list):
    # Thêm (i+1) để biết đang chạy đến đâu
    print(f"({i+1}/{len(vnstock_list)}) Đang tải: {symbol}...")
    
    try:
        quote = Quote(symbol=symbol, source='VCI')
        # Sửa lỗi 2: Dùng RESOLUTION ('1D') thay vì '1m'
        data = quote.history(start=START_DATE, end=today_str, interval=RESOLUTION)
        
        # Kiểm tra xem có dữ liệu trả về không
        if not data.empty:
            # Sửa lỗi 4: Thêm cột 'ticker' để nhận diện
            data['ticker'] = symbol 
            list_of_dfs.append(data)
        else:
            # Nếu data rỗng (mã mới, không có giao dịch...)
            print(f"  -> Không có dữ liệu cho {symbol} trong khoảng thời gian này.")
            symbol_no_data.append(symbol)

    except Exception as e:
        # Nếu API báo lỗi (mã không tìm thấy, lỗi mạng...)
        print(f"  -> Lỗi khi tải {symbol}: {e}")
        # Sửa lỗi 3: Dùng .append() đúng cách
        symbol_no_data.append(symbol) 
    
    # Thêm độ trễ để tránh làm quá tải server API
    time.sleep(DELAY_SECONDS)

# --- Bước 4: Tổng hợp dữ liệu ---
if list_of_dfs:
    print("\nĐang tổng hợp dữ liệu...")
    df_tong = pd.concat(list_of_dfs, ignore_index=True)
    
    print("--- HOÀN TẤT ---")
    print("DataFrame tổng (5 dòng đầu):")
    print(df_tong.head())
    print("\nDataFrame tổng (5 dòng cuối):")
    print(df_tong.tail())
else:
    print("\nKhông tải được dữ liệu nào, DataFrame tổng bị rỗng.")

print(f"\nCác mã không có dữ liệu hoặc bị lỗi: {len(symbol_no_data)}")
print(symbol_no_data)
# Out:
# Tìm thấy 1721 mã. Bắt đầu tải...
# (1/1721) Đang tải: YTC...
# (2/1721) Đang tải: YEG...
# (3/1721) Đang tải: YBM...
# (4/1721) Đang tải: YBC...
# (5/1721) Đang tải: XPH...
# (6/1721) Đang tải: XMP...
# (7/1721) Đang tải: XMD...
# (8/1721) Đang tải: XMC...
# (9/1721) Đang tải: XLV...
# (10/1721) Đang tải: XHC...
# (11/1721) Đang tải: XDH...
# (12/1721) Đang tải: XDC...
#   -> Lỗi khi tải XDC: RetryError[<Future at 0x22492534690 state=finished raised ValueError>]
# (13/1721) Đang tải: X77...
#   -> Lỗi khi tải X77: RetryError[<Future at 0x22492978450 state=finished raised ValueError>]
# (14/1721) Đang tải: X26...
# (15/1721) Đang tải: X20...
# (16/1721) Đang tải: WTC...
# (17/1721) Đang tải: WSS...
# (18/1721) Đang tải: WSB...
# (19/1721) Đang tải: WCS...
# (20/1721) Đang tải: VXT...
# (21/1721) Đang tải: VXP...
#   -> Lỗi khi tải VXP: RetryError[<Future at 0x2248f07e910 state=finished raised ValueError>]
# (22/1721) Đang tải: VXB...
# (23/1721) Đang tải: VWS...
# (24/1721) Đang tải: VW3...
# (25/1721) Đang tải: VVS...
# (26/1721) Đang tải: VVN...
# (27/1721) Đang tải: VUA...
# (28/1721) Đang tải: VTZ...
# (29/1721) Đang tải: VTX...
# (30/1721) Đang tải: VTV...
# (31/1721) Đang tải: VTS...
# (32/1721) Đang tải: VTR...
# (33/1721) Đang tải: VTQ...
# (34/1721) Đang tải: VTP...
# (35/1721) Đang tải: VTO...
# (36/1721) Đang tải: VTM...
#   -> Lỗi khi tải VTM: RetryError[<Future at 0x224911902d0 state=finished raised ValueError>]
# (37/1721) Đang tải: VTL...
# (38/1721) Đang tải: VTK...
# (39/1721) Đang tải: VTJ...
# (40/1721) Đang tải: VTI...
# (41/1721) Đang tải: VTH...
# (42/1721) Đang tải: VTG...
# (43/1721) Đang tải: VTE...
# (44/1721) Đang tải: VTD...
# (45/1721) Đang tải: VTC...
# (46/1721) Đang tải: VTB...
# (47/1721) Đang tải: VTA...
# (48/1721) Đang tải: VST...
# (49/1721) Đang tải: VSP...
#   -> Lỗi khi tải VSP: RetryError[<Future at 0x224904328d0 state=finished raised ValueError>]
# (50/1721) Đang tải: VSN...
# (51/1721) Đang tải: VSM...
# (52/1721) Đang tải: VSI...
# (53/1721) Đang tải: VSH...
# (54/1721) Đang tải: VSG...
# (55/1721) Đang tải: VSF...
# (56/1721) Đang tải: VSE...
# (57/1721) Đang tải: VSC...
# (58/1721) Đang tải: VSA...
# (59/1721) Đang tải: VRG...
# (60/1721) Đang tải: VRE...
# (61/1721) Đang tải: VRC...
# (62/1721) Đang tải: VQC...
# (63/1721) Đang tải: VPW...
# (64/1721) Đang tải: VPS...
# (65/1721) Đang tải: VPR...
# (66/1721) Đang tải: VPL...
# (67/1721) Đang tải: VPI...
# (68/1721) Đang tải: VPH...
# (69/1721) Đang tải: VPG...
# (70/1721) Đang tải: VPD...
# (71/1721) Đang tải: VPC...
# (72/1721) Đang tải: VPB...
# (73/1721) Đang tải: VPA...
# (74/1721) Đang tải: VOS...
# (75/1721) Đang tải: VOC...
# (76/1721) Đang tải: VNZ...
# (77/1721) Đang tải: VNY...
# (78/1721) Đang tải: VNX...
# (79/1721) Đang tải: VNT...
# (80/1721) Đang tải: VNS...
# (81/1721) Đang tải: VNR...
# (82/1721) Đang tải: VNP...
# (83/1721) Đang tải: VNM...
# (84/1721) Đang tải: VNL...
# (85/1721) Đang tải: VNI...
# (86/1721) Đang tải: VNH...
# (87/1721) Đang tải: VNG...
# (88/1721) Đang tải: VNF...
# (89/1721) Đang tải: VNE...
# (90/1721) Đang tải: VND...
# (91/1721) Đang tải: VNC...
# (92/1721) Đang tải: VNB...
# (93/1721) Đang tải: VNA...
# (94/1721) Đang tải: VMT...
# (95/1721) Đang tải: VMS...
# (96/1721) Đang tải: VMK...
# (97/1721) Đang tải: VMI...
#   -> Lỗi khi tải VMI: RetryError[<Future at 0x2248efc0a10 state=finished raised ValueError>]
# (98/1721) Đang tải: VMG...
# (99/1721) Đang tải: VMD...
# (100/1721) Đang tải: VMC...
# (101/1721) Đang tải: VMA...
# (102/1721) Đang tải: VLW...
# (103/1721) Đang tải: VLP...
#   -> Lỗi khi tải VLP: RetryError[<Future at 0x2248ef75d10 state=finished raised ValueError>]
# (104/1721) Đang tải: VLG...
# (105/1721) Đang tải: VLF...
# (106/1721) Đang tải: VLC...
# (107/1721) Đang tải: VLB...
# (108/1721) Đang tải: VLA...
# (109/1721) Đang tải: VKP...
#   -> Lỗi khi tải VKP: RetryError[<Future at 0x224924e9a10 state=finished raised ValueError>]
# (110/1721) Đang tải: VKD...
#   -> Lỗi khi tải VKD: RetryError[<Future at 0x22491192f50 state=finished raised ValueError>]
# (111/1721) Đang tải: VKC...
# (112/1721) Đang tải: VJC...
# (113/1721) Đang tải: VIX...
# (114/1721) Đang tải: VIW...
# (115/1721) Đang tải: VIT...
# (116/1721) Đang tải: VIS...
#   -> Lỗi khi tải VIS: RetryError[<Future at 0x22490abc8d0 state=finished raised ValueError>]
# (117/1721) Đang tải: VIR...
# (118/1721) Đang tải: VIP...
# (119/1721) Đang tải: VIN...
# (120/1721) Đang tải: VIM...
# (121/1721) Đang tải: VIH...
# (122/1721) Đang tải: VIG...
# (123/1721) Đang tải: VIF...
# (124/1721) Đang tải: VIE...
# (125/1721) Đang tải: VID...
# (126/1721) Đang tải: VIC...
# (127/1721) Đang tải: VIB...
# (128/1721) Đang tải: VHM...
# (129/1721) Đang tải: VHL...
# (130/1721) Đang tải: VHI...
#   -> Lỗi khi tải VHI: RetryError[<Future at 0x224911c6e90 state=finished raised ValueError>]
# (131/1721) Đang tải: VHH...
# (132/1721) Đang tải: VHG...
# (133/1721) Đang tải: VHF...
# (134/1721) Đang tải: VHE...
# (135/1721) Đang tải: VHD...
# (136/1721) Đang tải: VHC...
# (137/1721) Đang tải: VGV...
# (138/1721) Đang tải: VGT...
# (139/1721) Đang tải: VGS...
# (140/1721) Đang tải: VGR...
# (141/1721) Đang tải: VGP...
# (142/1721) Đang tải: VGL...
# (143/1721) Đang tải: VGI...
# (144/1721) Đang tải: VGG...
# (145/1721) Đang tải: VGC...
# (146/1721) Đang tải: VFS...
# (147/1721) Đang tải: VFR...
# (148/1721) Đang tải: VFG...
# (149/1721) Đang tải: VFC...
# (150/1721) Đang tải: VET...
# (151/1721) Đang tải: VES...
# (152/1721) Đang tải: VEF...
# (153/1721) Đang tải: VEC...
# (154/1721) Đang tải: VEA...
# (155/1721) Đang tải: VE9...
# (156/1721) Đang tải: VE8...
# (157/1721) Đang tải: VE4...
#   -> Lỗi khi tải VE4: RetryError[<Future at 0x2248ef84150 state=finished raised ValueError>]
# (158/1721) Đang tải: VE3...
# (159/1721) Đang tải: VE2...
# (160/1721) Đang tải: VE1...
# (161/1721) Đang tải: VDT...
# (162/1721) Đang tải: VDS...
# (163/1721) Đang tải: VDP...
# (164/1721) Đang tải: VDN...
# (165/1721) Đang tải: VDM...
#   -> Lỗi khi tải VDM: RetryError[<Future at 0x2249120ce10 state=finished raised ValueError>]
# (166/1721) Đang tải: VDL...
# (167/1721) Đang tải: VDG...
# (168/1721) Đang tải: VDB...
#   -> Lỗi khi tải VDB: RetryError[<Future at 0x22491230050 state=finished raised ValueError>]
# (169/1721) Đang tải: VCX...
# (170/1721) Đang tải: VCW...
# (171/1721) Đang tải: VCT...
# (172/1721) Đang tải: VCS...
# (173/1721) Đang tải: VCR...
# (174/1721) Đang tải: VCP...
# (175/1721) Đang tải: VCM...
# (176/1721) Đang tải: VCI...
# (177/1721) Đang tải: VCG...
# (178/1721) Đang tải: VCF...
# (179/1721) Đang tải: VCE...
#   -> Lỗi khi tải VCE: RetryError[<Future at 0x22491226f50 state=finished raised ValueError>]
# (180/1721) Đang tải: VCC...
# (181/1721) Đang tải: VCB...
# (182/1721) Đang tải: VCA...
# (183/1721) Đang tải: VC9...
# (184/1721) Đang tải: VC7...
# (185/1721) Đang tải: VC6...
# (186/1721) Đang tải: VC5...
# (187/1721) Đang tải: VC3...
# (188/1721) Đang tải: VC2...
# (189/1721) Đang tải: VC1...
# (190/1721) Đang tải: VBH...
# (191/1721) Đang tải: VBG...
# (192/1721) Đang tải: VBC...
# (193/1721) Đang tải: VBB...
# (194/1721) Đang tải: VAV...
# (195/1721) Đang tải: VAT...
#   -> Lỗi khi tải VAT: RetryError[<Future at 0x224924e7150 state=finished raised ValueError>]
# (196/1721) Đang tải: VAF...
# (197/1721) Đang tải: VAB...
# (198/1721) Đang tải: V21...
# (199/1721) Đang tải: V15...
#   -> Lỗi khi tải V15: RetryError[<Future at 0x22491232950 state=finished raised ValueError>]
# (200/1721) Đang tải: V12...
# (201/1721) Đang tải: V11...
# (202/1721) Đang tải: UXC...
# (203/1721) Đang tải: UTT...
#   -> Lỗi khi tải UTT: RetryError[<Future at 0x224911e6fd0 state=finished raised ValueError>]
# (204/1721) Đang tải: USD...
# (205/1721) Đang tải: USC...
# (206/1721) Đang tải: UPH...
# (207/1721) Đang tải: UPC...
# (208/1721) Đang tải: UNI...
# (209/1721) Đang tải: UMC...
# (210/1721) Đang tải: UIC...
# (211/1721) Đang tải: UEM...
# (212/1721) Đang tải: UDL...
# (213/1721) Đang tải: UDJ...
# (214/1721) Đang tải: UDC...
# (215/1721) Đang tải: UCT...
# (216/1721) Đang tải: TYA...
# (217/1721) Đang tải: TXM...
# (218/1721) Đang tải: TW3...
# (219/1721) Đang tải: TVW...
#   -> Lỗi khi tải TVW: RetryError[<Future at 0x22491248fd0 state=finished raised ValueError>]
# (220/1721) Đang tải: TVT...
# (221/1721) Đang tải: TVS...
# (222/1721) Đang tải: TVP...
#   -> Lỗi khi tải TVP: RetryError[<Future at 0x22490b09c90 state=finished raised ValueError>]
# (223/1721) Đang tải: TVN...
# (224/1721) Đang tải: TVM...
# (225/1721) Đang tải: TVH...
# (226/1721) Đang tải: TVG...
# (227/1721) Đang tải: TVD...
# (228/1721) Đang tải: TVC...
# (229/1721) Đang tải: TVB...
# (230/1721) Đang tải: TVA...
# (231/1721) Đang tải: TV6...
# (232/1721) Đang tải: TV4...
# (233/1721) Đang tải: TV3...
# (234/1721) Đang tải: TV2...
# (235/1721) Đang tải: TV1...
# (236/1721) Đang tải: TUG...
# (237/1721) Đang tải: TTZ...
#   -> Lỗi khi tải TTZ: RetryError[<Future at 0x22490ae4290 state=finished raised ValueError>]
# (238/1721) Đang tải: TTT...
# (239/1721) Đang tải: TTS...
# (240/1721) Đang tải: TTP...
# (241/1721) Đang tải: TTN...
# (242/1721) Đang tải: TTL...
# (243/1721) Đang tải: TTH...
# (244/1721) Đang tải: TTG...
# (245/1721) Đang tải: TTF...
# (246/1721) Đang tải: TTE...
# (247/1721) Đang tải: TTD...
# (248/1721) Đang tải: TTC...
# (249/1721) Đang tải: TTB...
#   -> Lỗi khi tải TTB: RetryError[<Future at 0x2249127a950 state=finished raised ValueError>]
# (250/1721) Đang tải: TTA...
# (251/1721) Đang tải: TT6...
# (252/1721) Đang tải: TST...
# (253/1721) Đang tải: TSJ...
# (254/1721) Đang tải: TSG...
# (255/1721) Đang tải: TSD...
# (256/1721) Đang tải: TSC...
# (257/1721) Đang tải: TSB...
# (258/1721) Đang tải: TSA...
# (259/1721) Đang tải: TS5...
#   -> Lỗi khi tải TS5: RetryError[<Future at 0x2249123d350 state=finished raised ValueError>]
# (260/1721) Đang tải: TS4...
#   -> Lỗi khi tải TS4: RetryError[<Future at 0x2249125ebd0 state=finished raised ValueError>]
# (261/1721) Đang tải: TS3...
# (262/1721) Đang tải: TRV...
# (263/1721) Đang tải: TRT...
# (264/1721) Đang tải: TRS...
# (265/1721) Đang tải: TRC...
# (266/1721) Đang tải: TRA...
# (267/1721) Đang tải: TR1...
# (268/1721) Đang tải: TQW...
# (269/1721) Đang tải: TQN...
# (270/1721) Đang tải: TPS...
# (271/1721) Đang tải: TPP...
# (272/1721) Đang tải: TPH...
# (273/1721) Đang tải: TPC...
# (274/1721) Đang tải: TPB...
# (275/1721) Đang tải: TOW...
# (276/1721) Đang tải: TOT...
# (277/1721) Đang tải: TOS...
# (278/1721) Đang tải: TOP...
# (279/1721) Đang tải: TNW...
# (280/1721) Đang tải: TNV...
# (281/1721) Đang tải: TNT...
# (282/1721) Đang tải: TNS...
# (283/1721) Đang tải: TNP...
# (284/1721) Đang tải: TNM...
#   -> Lỗi khi tải TNM: RetryError[<Future at 0x2248e6d8050 state=finished raised ValueError>]
# (285/1721) Đang tải: TNI...
# (286/1721) Đang tải: TNH...
# (287/1721) Đang tải: TNG...
# (288/1721) Đang tải: TNC...
# (289/1721) Đang tải: TNB...
# (290/1721) Đang tải: TNA...
#   -> Lỗi khi tải TNA: RetryError[<Future at 0x22490b795d0 state=finished raised ValueError>]
# (291/1721) Đang tải: TN1...
# (292/1721) Đang tải: TMX...
# (293/1721) Đang tải: TMW...
# (294/1721) Đang tải: TMT...
# (295/1721) Đang tải: TMS...
# (296/1721) Đang tải: TMP...
# (297/1721) Đang tải: TMG...
# (298/1721) Đang tải: TMC...
# (299/1721) Đang tải: TMB...
# (300/1721) Đang tải: TLT...
# (301/1721) Đang tải: TLP...
# (302/1721) Đang tải: TLI...
# (303/1721) Đang tải: TLH...
# (304/1721) Đang tải: TLG...
# (305/1721) Đang tải: TLD...
# (306/1721) Đang tải: TL4...
# (307/1721) Đang tải: TKU...
# (308/1721) Đang tải: TKG...
#   -> Lỗi khi tải TKG: RetryError[<Future at 0x22490b08110 state=finished raised ValueError>]
# (309/1721) Đang tải: TKC...
#   -> Lỗi khi tải TKC: RetryError[<Future at 0x2249113ff90 state=finished raised ValueError>]
# (310/1721) Đang tải: TKA...
# (311/1721) Đang tải: TJC...
# (312/1721) Đang tải: TIX...
# (313/1721) Đang tải: TIS...
# (314/1721) Đang tải: TIP...
# (315/1721) Đang tải: TIN...
# (316/1721) Đang tải: TIG...
# (317/1721) Đang tải: TIE...
# (318/1721) Đang tải: TID...
# (319/1721) Đang tải: THW...
# (320/1721) Đang tải: THU...
# (321/1721) Đang tải: THT...
# (322/1721) Đang tải: THS...
# (323/1721) Đang tải: THP...
# (324/1721) Đang tải: THN...
# (325/1721) Đang tải: THM...
# (326/1721) Đang tải: THI...
#   -> Lỗi khi tải THI: RetryError[<Future at 0x22492550190 state=finished raised ValueError>]
# (327/1721) Đang tải: THG...
# (328/1721) Đang tải: THD...
# (329/1721) Đang tải: THB...
# (330/1721) Đang tải: TH1...
# (331/1721) Đang tải: TGP...
# (332/1721) Đang tải: TGG...
#   -> Lỗi khi tải TGG: RetryError[<Future at 0x224911231d0 state=finished raised ValueError>]
# (333/1721) Đang tải: TFC...
# (334/1721) Đang tải: TET...
# (335/1721) Đang tải: TEL...
# (336/1721) Đang tải: TEG...
# (337/1721) Đang tải: TED...
# (338/1721) Đang tải: TEC...
#   -> Lỗi khi tải TEC: RetryError[<Future at 0x2249137cc90 state=finished raised ValueError>]
# (339/1721) Đang tải: TDW...
# (340/1721) Đang tải: TDT...
# (341/1721) Đang tải: TDS...
# (342/1721) Đang tải: TDP...
# (343/1721) Đang tải: TDN...
#   -> Lỗi khi tải TDN: RetryError[<Future at 0x22492adbd10 state=finished raised ValueError>]
# (344/1721) Đang tải: TDM...
# (345/1721) Đang tải: TDI...
#   -> Lỗi khi tải TDI: RetryError[<Future at 0x224919a0a50 state=finished raised ValueError>]
# (346/1721) Đang tải: TDH...
# (347/1721) Đang tải: TDG...
# (348/1721) Đang tải: TDF...
# (349/1721) Đang tải: TDC...
# (350/1721) Đang tải: TDB...
# (351/1721) Đang tải: TD6...
# (352/1721) Đang tải: TCW...
# (353/1721) Đang tải: TCT...
# (354/1721) Đang tải: TCR...
# (355/1721) Đang tải: TCO...
# (356/1721) Đang tải: TCM...
# (357/1721) Đang tải: TCL...
# (358/1721) Đang tải: TCK...
# (359/1721) Đang tải: TCJ...
# (360/1721) Đang tải: TCI...
# (361/1721) Đang tải: TCH...
# (362/1721) Đang tải: TCD...
# (363/1721) Đang tải: TCB...
# (364/1721) Đang tải: TC6...
#   -> Lỗi khi tải TC6: RetryError[<Future at 0x2249111aad0 state=finished raised ValueError>]
# (365/1721) Đang tải: TBX...
# (366/1721) Đang tải: TBW...
# (367/1721) Đang tải: TBT...
#   -> Lỗi khi tải TBT: RetryError[<Future at 0x22492b06d90 state=finished raised ValueError>]
# (368/1721) Đang tải: TBR...
# (369/1721) Đang tải: TBH...
#   -> Lỗi khi tải TBH: RetryError[<Future at 0x224912744d0 state=finished raised ValueError>]
# (370/1721) Đang tải: TBD...
# (371/1721) Đang tải: TBC...
# (372/1721) Đang tải: TB8...
# (373/1721) Đang tải: TAW...
# (374/1721) Đang tải: TAR...
# (375/1721) Đang tải: TAP...
#   -> Lỗi khi tải TAP: RetryError[<Future at 0x22491144fd0 state=finished raised ValueError>]
# (376/1721) Đang tải: TAN...
# (377/1721) Đang tải: TAL...
# (378/1721) Đang tải: TAG...
#   -> Lỗi khi tải TAG: RetryError[<Future at 0x2249137df50 state=finished raised ValueError>]
# (379/1721) Đang tải: TAC...
#   -> Lỗi khi tải TAC: RetryError[<Future at 0x2249254c2d0 state=finished raised ValueError>]
# (380/1721) Đang tải: TAB...
# (381/1721) Đang tải: TA9...
# (382/1721) Đang tải: TA6...
# (383/1721) Đang tải: TA3...
#   -> Lỗi khi tải TA3: RetryError[<Future at 0x224911c58d0 state=finished raised ValueError>]
# (384/1721) Đang tải: T12...
#   -> Lỗi khi tải T12: RetryError[<Future at 0x2248ef940d0 state=finished raised ValueError>]
# (385/1721) Đang tải: SZL...
# (386/1721) Đang tải: SZG...
# (387/1721) Đang tải: SZE...
# (388/1721) Đang tải: SZC...
# (389/1721) Đang tải: SZB...
# (390/1721) Đang tải: SWC...
# (391/1721) Đang tải: SVT...
# (392/1721) Đang tải: SVN...
# (393/1721) Đang tải: SVL...
#   -> Lỗi khi tải SVL: RetryError[<Future at 0x22490b16150 state=finished raised ValueError>]
# (394/1721) Đang tải: SVI...
# (395/1721) Đang tải: SVH...
#   -> Lỗi khi tải SVH: RetryError[<Future at 0x2249123cf10 state=finished raised ValueError>]
# (396/1721) Đang tải: SVG...
# (397/1721) Đang tải: SVD...
# (398/1721) Đang tải: SVC...
# (399/1721) Đang tải: STW...
# (400/1721) Đang tải: STT...
# (401/1721) Đang tải: STS...
# (402/1721) Đang tải: STP...
# (403/1721) Đang tải: STL...
#   -> Lỗi khi tải STL: RetryError[<Future at 0x2249254fd10 state=finished raised ValueError>]
# (404/1721) Đang tải: STK...
# (405/1721) Đang tải: STH...
# (406/1721) Đang tải: STG...
# (407/1721) Đang tải: STC...
# (408/1721) Đang tải: STB...
# (409/1721) Đang tải: ST8...
# (410/1721) Đang tải: SSU...
#   -> Lỗi khi tải SSU: RetryError[<Future at 0x22491287690 state=finished raised ValueError>]
# (411/1721) Đang tải: SSN...
# (412/1721) Đang tải: SSM...
# (413/1721) Đang tải: SSI...
# (414/1721) Đang tải: SSH...
# (415/1721) Đang tải: SSG...
# (416/1721) Đang tải: SSF...
#   -> Lỗi khi tải SSF: RetryError[<Future at 0x22490b684d0 state=finished raised ValueError>]
# (417/1721) Đang tải: SSC...
# (418/1721) Đang tải: SSB...
# (419/1721) Đang tải: SRT...
#   -> Lỗi khi tải SRT: RetryError[<Future at 0x224912576d0 state=finished raised ValueError>]
# (420/1721) Đang tải: SRF...
# (421/1721) Đang tải: SRC...
# (422/1721) Đang tải: SRB...
# (423/1721) Đang tải: SRA...
# (424/1721) Đang tải: SQC...
# (425/1721) Đang tải: SPV...
# (426/1721) Đang tải: SPP...
#   -> Lỗi khi tải SPP: RetryError[<Future at 0x22491909390 state=finished raised ValueError>]
# (427/1721) Đang tải: SPM...
# (428/1721) Đang tải: SPI...
# (429/1721) Đang tải: SPH...
# (430/1721) Đang tải: SPD...
# (431/1721) Đang tải: SPC...
# (432/1721) Đang tải: SPB...
# (433/1721) Đang tải: SPA...
#   -> Lỗi khi tải SPA: RetryError[<Future at 0x2249137d450 state=finished raised ValueError>]
# (434/1721) Đang tải: SP2...
# (435/1721) Đang tải: SON...
#   -> Lỗi khi tải SON: RetryError[<Future at 0x224918fd250 state=finished raised ValueError>]
# (436/1721) Đang tải: SNZ...
# (437/1721) Đang tải: SNC...
# (438/1721) Đang tải: SMT...
# (439/1721) Đang tải: SMN...
# (440/1721) Đang tải: SMC...
# (441/1721) Đang tải: SMB...
# (442/1721) Đang tải: SMA...
# (443/1721) Đang tải: SLS...
# (444/1721) Đang tải: SLD...
# (445/1721) Đang tải: SKV...
# (446/1721) Đang tải: SKN...
# (447/1721) Đang tải: SKH...
# (448/1721) Đang tải: SKG...
# (449/1721) Đang tải: SJS...
# (450/1721) Đang tải: SJM...
# (451/1721) Đang tải: SJG...
# (452/1721) Đang tải: SJF...
#   -> Lỗi khi tải SJF: RetryError[<Future at 0x22490619b50 state=finished raised ValueError>]
# (453/1721) Đang tải: SJE...
# (454/1721) Đang tải: SJD...
# (455/1721) Đang tải: SJC...
#   -> Lỗi khi tải SJC: RetryError[<Future at 0x224910a1010 state=finished raised ValueError>]
# (456/1721) Đang tải: SJ1...
# (457/1721) Đang tải: SIV...
# (458/1721) Đang tải: SIP...
# (459/1721) Đang tải: SII...
# (460/1721) Đang tải: SIG...
# (461/1721) Đang tải: SID...
# (462/1721) Đang tải: SIC...
#   -> Lỗi khi tải SIC: RetryError[<Future at 0x2249066a490 state=finished raised ValueError>]
# (463/1721) Đang tải: SHX...
#   -> Lỗi khi tải SHX: RetryError[<Future at 0x224906342d0 state=finished raised ValueError>]
# (464/1721) Đang tải: SHS...
# (465/1721) Đang tải: SHP...
# (466/1721) Đang tải: SHN...
# (467/1721) Đang tải: SHI...
# (468/1721) Đang tải: SHG...
# (469/1721) Đang tải: SHE...
# (470/1721) Đang tải: SHC...
# (471/1721) Đang tải: SHB...
# (472/1721) Đang tải: SHA...
# (473/1721) Đang tải: SGT...
# (474/1721) Đang tải: SGS...
# (475/1721) Đang tải: SGR...
# (476/1721) Đang tải: SGP...
# (477/1721) Đang tải: SGO...
#   -> Lỗi khi tải SGO: RetryError[<Future at 0x2249064a450 state=finished raised ValueError>]
# (478/1721) Đang tải: SGN...
# (479/1721) Đang tải: SGI...
# (480/1721) Đang tải: SGH...
# (481/1721) Đang tải: SGD...
# (482/1721) Đang tải: SGC...
# (483/1721) Đang tải: SGB...
# (484/1721) Đang tải: SFN...
# (485/1721) Đang tải: SFI...
# (486/1721) Đang tải: SFG...
# (487/1721) Đang tải: SFC...
# (488/1721) Đang tải: SEP...
# (489/1721) Đang tải: SED...
# (490/1721) Đang tải: SEB...
# (491/1721) Đang tải: SEA...
# (492/1721) Đang tải: SDY...
# (493/1721) Đang tải: SDX...
#   -> Lỗi khi tải SDX: RetryError[<Future at 0x22491122350 state=finished raised ValueError>]
# (494/1721) Đang tải: SDV...
# (495/1721) Đang tải: SDU...
# (496/1721) Đang tải: SDT...
# (497/1721) Đang tải: SDP...
# (498/1721) Đang tải: SDN...
# (499/1721) Đang tải: SDK...
# (500/1721) Đang tải: SDJ...
#   -> Lỗi khi tải SDJ: RetryError[<Future at 0x224906d8610 state=finished raised ValueError>]
# (501/1721) Đang tải: SDH...
#   -> Lỗi khi tải SDH: RetryError[<Future at 0x224906cc710 state=finished raised ValueError>]
# (502/1721) Đang tải: SDG...
# (503/1721) Đang tải: SDD...
# (504/1721) Đang tải: SDC...
# (505/1721) Đang tải: SDB...
#   -> Lỗi khi tải SDB: RetryError[<Future at 0x2249075ef90 state=finished raised ValueError>]
# (506/1721) Đang tải: SDA...
# (507/1721) Đang tải: SD9...
# (508/1721) Đang tải: SD8...
#   -> Lỗi khi tải SD8: RetryError[<Future at 0x22490648950 state=finished raised ValueError>]
# (509/1721) Đang tải: SD7...
# (510/1721) Đang tải: SD6...
# (511/1721) Đang tải: SD5...
# (512/1721) Đang tải: SD4...
# (513/1721) Đang tải: SD3...
# (514/1721) Đang tải: SD2...
# (515/1721) Đang tải: SD1...
#   -> Lỗi khi tải SD1: RetryError[<Future at 0x224906cd010 state=finished raised ValueError>]
# (516/1721) Đang tải: SCY...
# (517/1721) Đang tải: SCV...
#   -> Lỗi khi tải SCV: RetryError[<Future at 0x22490669ad0 state=finished raised ValueError>]
# (518/1721) Đang tải: SCS...
# (519/1721) Đang tải: SCR...
# (520/1721) Đang tải: SCO...
# (521/1721) Đang tải: SCL...
# (522/1721) Đang tải: SCJ...
# (523/1721) Đang tải: SCI...
# (524/1721) Đang tải: SCG...
# (525/1721) Đang tải: SCD...
# (526/1721) Đang tải: SCC...
# (527/1721) Đang tải: SCA...
#   -> Lỗi khi tải SCA: RetryError[<Future at 0x2248e1a7950 state=finished raised ValueError>]
# (528/1721) Đang tải: SC5...
# (529/1721) Đang tải: SBV...
# (530/1721) Đang tải: SBT...
# (531/1721) Đang tải: SBS...
# (532/1721) Đang tải: SBR...
# (533/1721) Đang tải: SBM...
# (534/1721) Đang tải: SBL...
# (535/1721) Đang tải: SBH...
# (536/1721) Đang tải: SBG...
# (537/1721) Đang tải: SBD...
# (538/1721) Đang tải: SBB...
# (539/1721) Đang tải: SBA...
# (540/1721) Đang tải: SB1...
# (541/1721) Đang tải: SAV...
# (542/1721) Đang tải: SAS...
# (543/1721) Đang tải: SAP...
# (544/1721) Đang tải: SAM...
# (545/1721) Đang tải: SAL...
# (546/1721) Đang tải: SAF...
# (547/1721) Đang tải: SAC...
# (548/1721) Đang tải: SAB...
# (549/1721) Đang tải: S99...
# (550/1721) Đang tải: S96...
#   -> Lỗi khi tải S96: RetryError[<Future at 0x224906daf50 state=finished raised ValueError>]
# (551/1721) Đang tải: S74...
# (552/1721) Đang tải: S72...
# (553/1721) Đang tải: S55...
# (554/1721) Đang tải: S4A...
# (555/1721) Đang tải: S27...
#   -> Lỗi khi tải S27: RetryError[<Future at 0x224907556d0 state=finished raised ValueError>]
# (556/1721) Đang tải: S12...
# (557/1721) Đang tải: RYG...
# (558/1721) Đang tải: RTB...
# (559/1721) Đang tải: ROS...
#   -> Lỗi khi tải ROS: RetryError[<Future at 0x22490799610 state=finished raised ValueError>]
# (560/1721) Đang tải: RIC...
# (561/1721) Đang tải: RGC...
#   -> Lỗi khi tải RGC: RetryError[<Future at 0x224906bf850 state=finished raised ValueError>]
# (562/1721) Đang tải: REE...
# (563/1721) Đang tải: RDP...
#   -> Lỗi khi tải RDP: RetryError[<Future at 0x224906a9f10 state=finished raised ValueError>]
# (564/1721) Đang tải: RCL...
# (565/1721) Đang tải: RCD...
# (566/1721) Đang tải: RCC...
# (567/1721) Đang tải: RBC...
# (568/1721) Đang tải: RAT...
# (569/1721) Đang tải: RAL...
# (570/1721) Đang tải: QTP...
# (571/1721) Đang tải: QTC...
# (572/1721) Đang tải: QST...
# (573/1721) Đang tải: QSP...
# (574/1721) Đang tải: QPH...
# (575/1721) Đang tải: QNW...
# (576/1721) Đang tải: QNU...
# (577/1721) Đang tải: QNT...
# (578/1721) Đang tải: QNS...
# (579/1721) Đang tải: QNP...
# (580/1721) Đang tải: QNC...
# (581/1721) Đang tải: QLT...
#   -> Lỗi khi tải QLT: RetryError[<Future at 0x22491286010 state=finished raised ValueError>]
# (582/1721) Đang tải: QLD...
#   -> Lỗi khi tải QLD: RetryError[<Future at 0x2249073b190 state=finished raised ValueError>]
# (583/1721) Đang tải: QHW...
# (584/1721) Đang tải: QHD...
# (585/1721) Đang tải: QCG...
# (586/1721) Đang tải: QCC...
# (587/1721) Đang tải: QBS...
# (588/1721) Đang tải: PYU...
#   -> Lỗi khi tải PYU: RetryError[<Future at 0x2249069a490 state=finished raised ValueError>]
# (589/1721) Đang tải: PXT...
# (590/1721) Đang tải: PXS...
# (591/1721) Đang tải: PXM...
# (592/1721) Đang tải: PXL...
# (593/1721) Đang tải: PXI...
# (594/1721) Đang tải: PXC...
#   -> Lỗi khi tải PXC: RetryError[<Future at 0x224906f6e10 state=finished raised ValueError>]
# (595/1721) Đang tải: PXA...
# (596/1721) Đang tải: PX1...
#   -> Lỗi khi tải PX1: RetryError[<Future at 0x2249066dd50 state=finished raised ValueError>]
# (597/1721) Đang tải: PWS...
# (598/1721) Đang tải: PWA...
# (599/1721) Đang tải: PVY...
# (600/1721) Đang tải: PVX...
# (601/1721) Đang tải: PVV...
# (602/1721) Đang tải: PVT...
# (603/1721) Đang tải: PVS...
# (604/1721) Đang tải: PVR...
# (605/1721) Đang tải: PVP...
# (606/1721) Đang tải: PVO...
# (607/1721) Đang tải: PVM...
# (608/1721) Đang tải: PVL...
# (609/1721) Đang tải: PVI...
# (610/1721) Đang tải: PVH...
# (611/1721) Đang tải: PVG...
# (612/1721) Đang tải: PVE...
# (613/1721) Đang tải: PVD...
# (614/1721) Đang tải: PVC...
# (615/1721) Đang tải: PVB...
# (616/1721) Đang tải: PVA...
#   -> Lỗi khi tải PVA: RetryError[<Future at 0x2249083abd0 state=finished raised ValueError>]
# (617/1721) Đang tải: PV2...
# (618/1721) Đang tải: PTX...
# (619/1721) Đang tải: PTV...
# (620/1721) Đang tải: PTT...
# (621/1721) Đang tải: PTS...
# (622/1721) Đang tải: PTP...
# (623/1721) Đang tải: PTO...
# (624/1721) Đang tải: PTN...
#   -> Lỗi khi tải PTN: RetryError[<Future at 0x2249064b390 state=finished raised ValueError>]
# (625/1721) Đang tải: PTM...
# (626/1721) Đang tải: PTL...
# (627/1721) Đang tải: PTI...
# (628/1721) Đang tải: PTH...
# (629/1721) Đang tải: PTG...
# (630/1721) Đang tải: PTE...
# (631/1721) Đang tải: PTD...
# (632/1721) Đang tải: PTC...
# (633/1721) Đang tải: PTB...
# (634/1721) Đang tải: PSW...
# (635/1721) Đang tải: PSP...
# (636/1721) Đang tải: PSN...
# (637/1721) Đang tải: PSL...
# (638/1721) Đang tải: PSI...
# (639/1721) Đang tải: PSH...
# (640/1721) Đang tải: PSG...
#   -> Lỗi khi tải PSG: RetryError[<Future at 0x22490875d50 state=finished raised ValueError>]
# (641/1721) Đang tải: PSE...
# (642/1721) Đang tải: PSD...
# (643/1721) Đang tải: PSC...
# (644/1721) Đang tải: PSB...
# (645/1721) Đang tải: PRT...
# (646/1721) Đang tải: PRO...
# (647/1721) Đang tải: PRE...
# (648/1721) Đang tải: PRC...
# (649/1721) Đang tải: PQN...
#   -> Lỗi khi tải PQN: RetryError[<Future at 0x22490634f90 state=finished raised ValueError>]
# (650/1721) Đang tải: PPY...
# (651/1721) Đang tải: PPT...
# (652/1721) Đang tải: PPS...
# (653/1721) Đang tải: PPP...
# (654/1721) Đang tải: PPI...
#   -> Lỗi khi tải PPI: RetryError[<Future at 0x224907a5410 state=finished raised ValueError>]
# (655/1721) Đang tải: PPH...
# (656/1721) Đang tải: PPE...
# (657/1721) Đang tải: PPC...
# (658/1721) Đang tải: POW...
# (659/1721) Đang tải: POV...
# (660/1721) Đang tải: POT...
# (661/1721) Đang tải: POS...
# (662/1721) Đang tải: POM...
# (663/1721) Đang tải: POB...
# (664/1721) Đang tải: PNT...
# (665/1721) Đang tải: PNP...
# (666/1721) Đang tải: PNJ...
# (667/1721) Đang tải: PNG...
# (668/1721) Đang tải: PND...
# (669/1721) Đang tải: PNC...
# (670/1721) Đang tải: PMW...
# (671/1721) Đang tải: PMT...
# (672/1721) Đang tải: PMS...
# (673/1721) Đang tải: PMP...
# (674/1721) Đang tải: PMJ...
# (675/1721) Đang tải: PMG...
# (676/1721) Đang tải: PMC...
# (677/1721) Đang tải: PMB...
# (678/1721) Đang tải: PLX...
# (679/1721) Đang tải: PLP...
# (680/1721) Đang tải: PLO...
# (681/1721) Đang tải: PLE...
# (682/1721) Đang tải: PLC...
# (683/1721) Đang tải: PLA...
# (684/1721) Đang tải: PJT...
# (685/1721) Đang tải: PJS...
# (686/1721) Đang tải: PJC...
# (687/1721) Đang tải: PIV...
# (688/1721) Đang tải: PIT...
# (689/1721) Đang tải: PIS...
# (690/1721) Đang tải: PID...
#   -> Lỗi khi tải PID: RetryError[<Future at 0x2249090d1d0 state=finished raised ValueError>]
# (691/1721) Đang tải: PIC...
# (692/1721) Đang tải: PIA...
# (693/1721) Đang tải: PHS...
# (694/1721) Đang tải: PHR...
# (695/1721) Đang tải: PHP...
# (696/1721) Đang tải: PHN...
# (697/1721) Đang tải: PHH...
# (698/1721) Đang tải: PHC...
# (699/1721) Đang tải: PGV...
# (700/1721) Đang tải: PGT...
# (701/1721) Đang tải: PGS...
# (702/1721) Đang tải: PGN...
# (703/1721) Đang tải: PGI...
# (704/1721) Đang tải: PGD...
# (705/1721) Đang tải: PGC...
# (706/1721) Đang tải: PGB...
# (707/1721) Đang tải: PFL...
# (708/1721) Đang tải: PET...
# (709/1721) Đang tải: PEQ...
# (710/1721) Đang tải: PEN...
# (711/1721) Đang tải: PEG...
# (712/1721) Đang tải: PEC...
# (713/1721) Đang tải: PDV...
# (714/1721) Đang tải: PDT...
#   -> Lỗi khi tải PDT: RetryError[<Future at 0x224907b9f50 state=finished raised ValueError>]
# (715/1721) Đang tải: PDR...
# (716/1721) Đang tải: PDN...
# (717/1721) Đang tải: PDC...
# (718/1721) Đang tải: PDB...
# (719/1721) Đang tải: PCT...
# (720/1721) Đang tải: PCN...
#   -> Lỗi khi tải PCN: RetryError[<Future at 0x2249083bbd0 state=finished raised ValueError>]
# (721/1721) Đang tải: PCM...
# (722/1721) Đang tải: PCH...
# (723/1721) Đang tải: PCG...
# (724/1721) Đang tải: PCF...
# (725/1721) Đang tải: PCE...
# (726/1721) Đang tải: PCC...
# (727/1721) Đang tải: PC1...
# (728/1721) Đang tải: PBT...
# (729/1721) Đang tải: PBP...
# (730/1721) Đang tải: PBC...
# (731/1721) Đang tải: PAT...
# (732/1721) Đang tải: PAS...
# (733/1721) Đang tải: PAP...
# (734/1721) Đang tải: PAN...
# (735/1721) Đang tải: PAI...
# (736/1721) Đang tải: PAC...
# (737/1721) Đang tải: ORS...
# (738/1721) Đang tải: OPC...
# (739/1721) Đang tải: ONW...
# (740/1721) Đang tải: ONE...
# (741/1721) Đang tải: OIL...
# (742/1721) Đang tải: OGC...
# (743/1721) Đang tải: ODE...
# (744/1721) Đang tải: OCH...
# (745/1721) Đang tải: OCB...
# (746/1721) Đang tải: NXT...
# (747/1721) Đang tải: NWT...
# (748/1721) Đang tải: NVT...
# (749/1721) Đang tải: NVP...
# (750/1721) Đang tải: NVL...
# (751/1721) Đang tải: NVB...
# (752/1721) Đang tải: NUE...
# (753/1721) Đang tải: NTW...
# (754/1721) Đang tải: NTT...
# (755/1721) Đang tải: NTP...
# (756/1721) Đang tải: NTL...
# (757/1721) Đang tải: NTH...
# (758/1721) Đang tải: NTF...
# (759/1721) Đang tải: NTC...
# (760/1721) Đang tải: NTB...
#   -> Lỗi khi tải NTB: RetryError[<Future at 0x224907a7f90 state=finished raised ValueError>]
# (761/1721) Đang tải: NT2...
# (762/1721) Đang tải: NST...
# (763/1721) Đang tải: NSS...
#   -> Lỗi khi tải NSS: RetryError[<Future at 0x2249091f5d0 state=finished raised ValueError>]
# (764/1721) Đang tải: NSL...
# (765/1721) Đang tải: NSH...
# (766/1721) Đang tải: NSG...
# (767/1721) Đang tải: NSC...
# (768/1721) Đang tải: NS3...
#   -> Lỗi khi tải NS3: RetryError[<Future at 0x224909dd810 state=finished raised ValueError>]
# (769/1721) Đang tải: NS2...
# (770/1721) Đang tải: NRC...
# (771/1721) Đang tải: NQT...
# (772/1721) Đang tải: NQN...
# (773/1721) Đang tải: NQB...
# (774/1721) Đang tải: NOS...
# (775/1721) Đang tải: NO1...
# (776/1721) Đang tải: NNT...
# (777/1721) Đang tải: NNQ...
#   -> Lỗi khi tải NNQ: RetryError[<Future at 0x224909cdcd0 state=finished raised ValueError>]
# (778/1721) Đang tải: NNG...
#   -> Lỗi khi tải NNG: RetryError[<Future at 0x22490746490 state=finished raised ValueError>]
# (779/1721) Đang tải: NNC...
# (780/1721) Đang tải: NLS...
# (781/1721) Đang tải: NLG...
# (782/1721) Đang tải: NKG...
# (783/1721) Đang tải: NJC...
# (784/1721) Đang tải: NHV...
# (785/1721) Đang tải: NHT...
# (786/1721) Đang tải: NHP...
#   -> Lỗi khi tải NHP: RetryError[<Future at 0x22490a08450 state=finished raised ValueError>]
# (787/1721) Đang tải: NHH...
# (788/1721) Đang tải: NHC...
# (789/1721) Đang tải: NHA...
# (790/1721) Đang tải: NGC...
# (791/1721) Đang tải: NFC...
# (792/1721) Đang tải: NET...
# (793/1721) Đang tải: NEM...
# (794/1721) Đang tải: NED...
# (795/1721) Đang tải: NDX...
# (796/1721) Đang tải: NDW...
# (797/1721) Đang tải: NDT...
# (798/1721) Đang tải: NDP...
# (799/1721) Đang tải: NDN...
# (800/1721) Đang tải: NDF...
#   -> Lỗi khi tải NDF: RetryError[<Future at 0x224907e5090 state=finished raised ValueError>]
# (801/1721) Đang tải: NDC...
# (802/1721) Đang tải: ND2...
# (803/1721) Đang tải: NCT...
# (804/1721) Đang tải: NCS...
# (805/1721) Đang tải: NCG...
# (806/1721) Đang tải: NBW...
# (807/1721) Đang tải: NBT...
# (808/1721) Đang tải: NBP...
# (809/1721) Đang tải: NBE...
# (810/1721) Đang tải: NBC...
# (811/1721) Đang tải: NBB...
# (812/1721) Đang tải: NAW...
# (813/1721) Đang tải: NAV...
# (814/1721) Đang tải: NAU...
# (815/1721) Đang tải: NAS...
# (816/1721) Đang tải: NAP...
# (817/1721) Đang tải: NAG...
# (818/1721) Đang tải: NAF...
# (819/1721) Đang tải: NAC...
# (820/1721) Đang tải: NAB...
# (821/1721) Đang tải: MZG...
# (822/1721) Đang tải: MXC...
#   -> Lỗi khi tải MXC: RetryError[<Future at 0x2249066e590 state=finished raised ValueError>]
# (823/1721) Đang tải: MWG...
# (824/1721) Đang tải: MVN...
# (825/1721) Đang tải: MVC...
# (826/1721) Đang tải: MVB...
# (827/1721) Đang tải: MTX...
# (828/1721) Đang tải: MTV...
# (829/1721) Đang tải: MTS...
# (830/1721) Đang tải: MTP...
# (831/1721) Đang tải: MTL...
# (832/1721) Đang tải: MTH...
# (833/1721) Đang tải: MTG...
# (834/1721) Đang tải: MTC...
# (835/1721) Đang tải: MTB...
#   -> Lỗi khi tải MTB: RetryError[<Future at 0x22490a0ab10 state=finished raised ValueError>]
# (836/1721) Đang tải: MTA...
# (837/1721) Đang tải: MST...
# (838/1721) Đang tải: MSR...
# (839/1721) Đang tải: MSN...
# (840/1721) Đang tải: MSH...
# (841/1721) Đang tải: MSB...
# (842/1721) Đang tải: MRF...
# (843/1721) Đang tải: MQN...
# (844/1721) Đang tải: MQB...
# (845/1721) Đang tải: MPY...
#   -> Lỗi khi tải MPY: RetryError[<Future at 0x224909992d0 state=finished raised ValueError>]
# (846/1721) Đang tải: MPT...
# (847/1721) Đang tải: MPC...
# (848/1721) Đang tải: MND...
# (849/1721) Đang tải: MNB...
# (850/1721) Đang tải: MML...
# (851/1721) Đang tải: MLS...
# (852/1721) Đang tải: MLC...
# (853/1721) Đang tải: MKV...
# (854/1721) Đang tải: MKP...
# (855/1721) Đang tải: MIM...
#   -> Lỗi khi tải MIM: RetryError[<Future at 0x224909e3910 state=finished raised ValueError>]
# (856/1721) Đang tải: MIG...
# (857/1721) Đang tải: MIE...
# (858/1721) Đang tải: MIC...
# (859/1721) Đang tải: MHL...
#   -> Lỗi khi tải MHL: RetryError[<Future at 0x22490cd3c90 state=finished raised ValueError>]
# (860/1721) Đang tải: MHC...
# (861/1721) Đang tải: MH3...
# (862/1721) Đang tải: MGR...
# (863/1721) Đang tải: MGG...
# (864/1721) Đang tải: MGC...
# (865/1721) Đang tải: MFS...
# (866/1721) Đang tải: MES...
#   -> Lỗi khi tải MES: RetryError[<Future at 0x2249094a890 state=finished raised ValueError>]
# (867/1721) Đang tải: MEL...
# (868/1721) Đang tải: MEG...
#   -> Lỗi khi tải MEG: RetryError[<Future at 0x22491296a10 state=finished raised ValueError>]
# (869/1721) Đang tải: MEF...
# (870/1721) Đang tải: MED...
# (871/1721) Đang tải: MEC...
# (872/1721) Đang tải: MDG...
# (873/1721) Đang tải: MDF...
# (874/1721) Đang tải: MDC...
# (875/1721) Đang tải: MDA...
# (876/1721) Đang tải: MCP...
# (877/1721) Đang tải: MCO...
# (878/1721) Đang tải: MCM...
# (879/1721) Đang tải: MCI...
#   -> Lỗi khi tải MCI: RetryError[<Future at 0x224909de9d0 state=finished raised ValueError>]
# (880/1721) Đang tải: MCH...
# (881/1721) Đang tải: MCG...
# (882/1721) Đang tải: MCF...
# (883/1721) Đang tải: MCD...
#   -> Lỗi khi tải MCD: RetryError[<Future at 0x22490cc3a10 state=finished raised ValueError>]
# (884/1721) Đang tải: MCC...
# (885/1721) Đang tải: MC3...
#   -> Lỗi khi tải MC3: RetryError[<Future at 0x224906fb350 state=finished raised ValueError>]
# (886/1721) Đang tải: MBT...
# (887/1721) Đang tải: MBS...
# (888/1721) Đang tải: MBN...
#   -> Lỗi khi tải MBN: RetryError[<Future at 0x2249190b990 state=finished raised ValueError>]
# (889/1721) Đang tải: MBG...
# (890/1721) Đang tải: MBB...
# (891/1721) Đang tải: MAS...
# (892/1721) Đang tải: MAC...
# (893/1721) Đang tải: MA1...
# (894/1721) Đang tải: M10...
# (895/1721) Đang tải: LYF...
#   -> Lỗi khi tải LYF: RetryError[<Future at 0x22491920b90 state=finished raised ValueError>]
# (896/1721) Đang tải: LWS...
#   -> Lỗi khi tải LWS: RetryError[<Future at 0x224918b91d0 state=finished raised ValueError>]
# (897/1721) Đang tải: LUT...
# (898/1721) Đang tải: LTG...
# (899/1721) Đang tải: LTC...
# (900/1721) Đang tải: LSS...
# (901/1721) Đang tải: LSG...
# (902/1721) Đang tải: LQN...
# (903/1721) Đang tải: LPT...
# (904/1721) Đang tải: LPB...
# (905/1721) Đang tải: LO5...
# (906/1721) Đang tải: LNC...
# (907/1721) Đang tải: LMI...
# (908/1721) Đang tải: LMH...
# (909/1721) Đang tải: LMC...
# (910/1721) Đang tải: LM8...
# (911/1721) Đang tải: LM7...
# (912/1721) Đang tải: LM3...
# (913/1721) Đang tải: LLM...
# (914/1721) Đang tải: LKW...
# (915/1721) Đang tải: LIX...
# (916/1721) Đang tải: LIG...
# (917/1721) Đang tải: LIC...
# (918/1721) Đang tải: LHG...
# (919/1721) Đang tải: LHC...
# (920/1721) Đang tải: LGM...
# (921/1721) Đang tải: LGL...
# (922/1721) Đang tải: LGC...
# (923/1721) Đang tải: LG9...
# (924/1721) Đang tải: LEC...
# (925/1721) Đang tải: LDW...
# (926/1721) Đang tải: LDP...
# (927/1721) Đang tải: LDG...
# (928/1721) Đang tải: LCW...
#   -> Lỗi khi tải LCW: RetryError[<Future at 0x22492922710 state=finished raised ValueError>]
# (929/1721) Đang tải: LCS...
# (930/1721) Đang tải: LCM...
# (931/1721) Đang tải: LCG...
# (932/1721) Đang tải: LCD...
# (933/1721) Đang tải: LCC...
# (934/1721) Đang tải: LBM...
# (935/1721) Đang tải: LBE...
# (936/1721) Đang tải: LBC...
#   -> Lỗi khi tải LBC: RetryError[<Future at 0x22490d31690 state=finished raised ValueError>]
# (937/1721) Đang tải: LAW...
# (938/1721) Đang tải: LAS...
# (939/1721) Đang tải: LAI...
# (940/1721) Đang tải: LAF...
# (941/1721) Đang tải: L63...
# (942/1721) Đang tải: L62...
# (943/1721) Đang tải: L61...
# (944/1721) Đang tải: L45...
# (945/1721) Đang tải: L44...
# (946/1721) Đang tải: L43...
# (947/1721) Đang tải: L40...
# (948/1721) Đang tải: L35...
# (949/1721) Đang tải: L18...
# (950/1721) Đang tải: L14...
# (951/1721) Đang tải: L12...
# (952/1721) Đang tải: L10...
# (953/1721) Đang tải: KWA...
# (954/1721) Đang tải: KVC...
# (955/1721) Đang tải: KTW...
#   -> Lỗi khi tải KTW: RetryError[<Future at 0x2248e40a450 state=finished raised ValueError>]
# (956/1721) Đang tải: KTT...
#   -> Lỗi khi tải KTT: RetryError[<Future at 0x2248ea16450 state=finished raised ValueError>]
# (957/1721) Đang tải: KTS...
# (958/1721) Đang tải: KTL...
# (959/1721) Đang tải: KTC...
# (960/1721) Đang tải: KSV...
# (961/1721) Đang tải: KST...
# (962/1721) Đang tải: KSQ...
# (963/1721) Đang tải: KSH...
#   -> Lỗi khi tải KSH: RetryError[<Future at 0x2248e629550 state=finished raised ValueError>]
# (964/1721) Đang tải: KSF...
# (965/1721) Đang tải: KSD...
# (966/1721) Đang tải: KSB...
# (967/1721) Đang tải: KPF...
# (968/1721) Đang tải: KOS...
# (969/1721) Đang tải: KMT...
# (970/1721) Đang tải: KMR...
# (971/1721) Đang tải: KLM...
#   -> Lỗi khi tải KLM: RetryError[<Future at 0x2248ef6f210 state=finished raised ValueError>]
# (972/1721) Đang tải: KLF...
#   -> Lỗi khi tải KLF: RetryError[<Future at 0x22490ca7750 state=finished raised ValueError>]
# (973/1721) Đang tải: KLB...
# (974/1721) Đang tải: KKC...
# (975/1721) Đang tải: KIP...
# (976/1721) Đang tải: KHW...
# (977/1721) Đang tải: KHS...
# (978/1721) Đang tải: KHP...
# (979/1721) Đang tải: KHL...
#   -> Lỗi khi tải KHL: RetryError[<Future at 0x224918f5410 state=finished raised ValueError>]
# (980/1721) Đang tải: KHG...
# (981/1721) Đang tải: KHD...
# (982/1721) Đang tải: KHB...
#   -> Lỗi khi tải KHB: RetryError[<Future at 0x2249296eed0 state=finished raised ValueError>]
# (983/1721) Đang tải: KHA...
#   -> Lỗi khi tải KHA: RetryError[<Future at 0x22490d15210 state=finished raised ValueError>]
# (984/1721) Đang tải: KGM...
# (985/1721) Đang tải: KDM...
# (986/1721) Đang tải: KDH...
# (987/1721) Đang tải: KDC...
# (988/1721) Đang tải: KCE...
# (989/1721) Đang tải: KCB...
# (990/1721) Đang tải: KBC...
# (991/1721) Đang tải: KAC...
#   -> Lỗi khi tải KAC: RetryError[<Future at 0x2248ef825d0 state=finished raised ValueError>]
# (992/1721) Đang tải: JVC...
# (993/1721) Đang tải: JOS...
# (994/1721) Đang tải: IVS...
# (995/1721) Đang tải: ITS...
# (996/1721) Đang tải: ITQ...
# (997/1721) Đang tải: ITD...
# (998/1721) Đang tải: ITC...
# (999/1721) Đang tải: ITA...
#   -> Lỗi khi tải ITA: RetryError[<Future at 0x2249066ee50 state=finished raised ValueError>]
# (1000/1721) Đang tải: IST...
# (1001/1721) Đang tải: ISH...
# (1002/1721) Đang tải: ISG...
# (1003/1721) Đang tải: IRC...
# (1004/1721) Đang tải: IPH...
#   -> Lỗi khi tải IPH: RetryError[<Future at 0x2248f09c110 state=finished raised ValueError>]
# (1005/1721) Đang tải: IPA...
# (1006/1721) Đang tải: INN...
# (1007/1721) Đang tải: ING...
# (1008/1721) Đang tải: INC...
# (1009/1721) Đang tải: IN4...
# (1010/1721) Đang tải: IMP...
# (1011/1721) Đang tải: IME...
# (1012/1721) Đang tải: ILS...
# (1013/1721) Đang tải: ILC...
# (1014/1721) Đang tải: ILB...
# (1015/1721) Đang tải: ILA...
# (1016/1721) Đang tải: IJC...
# (1017/1721) Đang tải: IHK...
# (1018/1721) Đang tải: IFS...
# (1019/1721) Đang tải: IDV...
# (1020/1721) Đang tải: IDP...
# (1021/1721) Đang tải: IDJ...
# (1022/1721) Đang tải: IDI...
# (1023/1721) Đang tải: IDC...
# (1024/1721) Đang tải: ICT...
# (1025/1721) Đang tải: ICN...
# (1026/1721) Đang tải: ICI...
# (1027/1721) Đang tải: ICG...
# (1028/1721) Đang tải: ICF...
# (1029/1721) Đang tải: ICC...
# (1030/1721) Đang tải: IBN...
#   -> Lỗi khi tải IBN: RetryError[<Future at 0x224909f5a10 state=finished raised ValueError>]
# (1031/1721) Đang tải: IBD...
# (1032/1721) Đang tải: IBC...
#   -> Lỗi khi tải IBC: RetryError[<Future at 0x22490ca61d0 state=finished raised ValueError>]
# (1033/1721) Đang tải: HWS...
# (1034/1721) Đang tải: HVX...
# (1035/1721) Đang tải: HVT...
# (1036/1721) Đang tải: HVN...
# (1037/1721) Đang tải: HVH...
# (1038/1721) Đang tải: HVG...
#   -> Lỗi khi tải HVG: RetryError[<Future at 0x2249254f850 state=finished raised ValueError>]
# (1039/1721) Đang tải: HVA...
# (1040/1721) Đang tải: HUX...
#   -> Lỗi khi tải HUX: RetryError[<Future at 0x224903fec10 state=finished raised ValueError>]
# (1041/1721) Đang tải: HUT...
# (1042/1721) Đang tải: HUG...
# (1043/1721) Đang tải: HUB...
# (1044/1721) Đang tải: HU6...
# (1045/1721) Đang tải: HU4...
# (1046/1721) Đang tải: HU3...
# (1047/1721) Đang tải: HU1...
# (1048/1721) Đang tải: HTW...
#   -> Lỗi khi tải HTW: RetryError[<Future at 0x2248efd4110 state=finished raised ValueError>]
# (1049/1721) Đang tải: HTV...
# (1050/1721) Đang tải: HTT...
# (1051/1721) Đang tải: HTR...
#   -> Lỗi khi tải HTR: RetryError[<Future at 0x22492536610 state=finished raised ValueError>]
# (1052/1721) Đang tải: HTP...
# (1053/1721) Đang tải: HTN...
# (1054/1721) Đang tải: HTM...
# (1055/1721) Đang tải: HTL...
# (1056/1721) Đang tải: HTK...
#   -> Lỗi khi tải HTK: RetryError[<Future at 0x224925292d0 state=finished raised ValueError>]
# (1057/1721) Đang tải: HTI...
# (1058/1721) Đang tải: HTH...
#   -> Lỗi khi tải HTH: RetryError[<Future at 0x224909075d0 state=finished raised ValueError>]
# (1059/1721) Đang tải: HTG...
# (1060/1721) Đang tải: HTE...
# (1061/1721) Đang tải: HTC...
# (1062/1721) Đang tải: HT1...
# (1063/1721) Đang tải: HSV...
# (1064/1721) Đang tải: HSP...
# (1065/1721) Đang tải: HSM...
# (1066/1721) Đang tải: HSL...
# (1067/1721) Đang tải: HSI...
# (1068/1721) Đang tải: HSG...
# (1069/1721) Đang tải: HSA...
#   -> Lỗi khi tải HSA: RetryError[<Future at 0x22492b5b850 state=finished raised ValueError>]
# (1070/1721) Đang tải: HRT...
#   -> Lỗi khi tải HRT: RetryError[<Future at 0x2249193b510 state=finished raised ValueError>]
# (1071/1721) Đang tải: HRC...
# (1072/1721) Đang tải: HRB...
# (1073/1721) Đang tải: HQC...
# (1074/1721) Đang tải: HPX...
# (1075/1721) Đang tải: HPW...
# (1076/1721) Đang tải: HPT...
# (1077/1721) Đang tải: HPP...
# (1078/1721) Đang tải: HPM...
# (1079/1721) Đang tải: HPI...
# (1080/1721) Đang tải: HPH...
# (1081/1721) Đang tải: HPG...
# (1082/1721) Đang tải: HPD...
# (1083/1721) Đang tải: HPB...
# (1084/1721) Đang tải: HOT...
# (1085/1721) Đang tải: HOM...
# (1086/1721) Đang tải: HNT...
#   -> Lỗi khi tải HNT: RetryError[<Future at 0x224904311d0 state=finished raised ValueError>]
# (1087/1721) Đang tải: HNR...
#   -> Lỗi khi tải HNR: RetryError[<Future at 0x22492b74e90 state=finished raised ValueError>]
# (1088/1721) Đang tải: HNP...
# (1089/1721) Đang tải: HNM...
# (1090/1721) Đang tải: HNI...
# (1091/1721) Đang tải: HNG...
# (1092/1721) Đang tải: HNF...
# (1093/1721) Đang tải: HNE...
#   -> Lỗi khi tải HNE: RetryError[<Future at 0x224903e6750 state=finished raised ValueError>]
# (1094/1721) Đang tải: HND...
# (1095/1721) Đang tải: HNB...
# (1096/1721) Đang tải: HNA...
# (1097/1721) Đang tải: HMS...
# (1098/1721) Đang tải: HMR...
# (1099/1721) Đang tải: HMH...
# (1100/1721) Đang tải: HMG...
# (1101/1721) Đang tải: HMD...
# (1102/1721) Đang tải: HMC...
# (1103/1721) Đang tải: HLY...
# (1104/1721) Đang tải: HLT...
#   -> Lỗi khi tải HLT: RetryError[<Future at 0x2248ef84950 state=finished raised ValueError>]
# (1105/1721) Đang tải: HLS...
# (1106/1721) Đang tải: HLR...
#   -> Lỗi khi tải HLR: RetryError[<Future at 0x224924e5590 state=finished raised ValueError>]
# (1107/1721) Đang tải: HLO...
# (1108/1721) Đang tải: HLG...
#   -> Lỗi khi tải HLG: RetryError[<Future at 0x22492500150 state=finished raised ValueError>]
# (1109/1721) Đang tải: HLE...
#   -> Lỗi khi tải HLE: RetryError[<Future at 0x22490430410 state=finished raised ValueError>]
# (1110/1721) Đang tải: HLD...
# (1111/1721) Đang tải: HLC...
# (1112/1721) Đang tải: HLB...
# (1113/1721) Đang tải: HLA...
#   -> Lỗi khi tải HLA: RetryError[<Future at 0x2248ea10d10 state=finished raised ValueError>]
# (1114/1721) Đang tải: HKT...
# (1115/1721) Đang tải: HKP...
#   -> Lỗi khi tải HKP: RetryError[<Future at 0x224924c3010 state=finished raised ValueError>]
# (1116/1721) Đang tải: HKB...
# (1117/1721) Đang tải: HJS...
# (1118/1721) Đang tải: HJC...
# (1119/1721) Đang tải: HIO...
# (1120/1721) Đang tải: HII...
# (1121/1721) Đang tải: HIG...
# (1122/1721) Đang tải: HID...
# (1123/1721) Đang tải: HHV...
# (1124/1721) Đang tải: HHS...
# (1125/1721) Đang tải: HHR...
#   -> Lỗi khi tải HHR: RetryError[<Future at 0x22490b71450 state=finished raised ValueError>]
# (1126/1721) Đang tải: HHP...
# (1127/1721) Đang tải: HHN...
# (1128/1721) Đang tải: HHG...
# (1129/1721) Đang tải: HHC...
# (1130/1721) Đang tải: HGW...
#   -> Lỗi khi tải HGW: RetryError[<Future at 0x22492512790 state=finished raised ValueError>]
# (1131/1721) Đang tải: HGT...
# (1132/1721) Đang tải: HGR...
#   -> Lỗi khi tải HGR: RetryError[<Future at 0x22492adb7d0 state=finished raised ValueError>]
# (1133/1721) Đang tải: HGM...
# (1134/1721) Đang tải: HGC...
#   -> Lỗi khi tải HGC: RetryError[<Future at 0x22492500ad0 state=finished raised ValueError>]
# (1135/1721) Đang tải: HGA...
#   -> Lỗi khi tải HGA: RetryError[<Future at 0x224924e5c10 state=finished raised ValueError>]
# (1136/1721) Đang tải: HFX...
# (1137/1721) Đang tải: HFC...
# (1138/1721) Đang tải: HFB...
# (1139/1721) Đang tải: HEV...
# (1140/1721) Đang tải: HES...
# (1141/1721) Đang tải: HEP...
# (1142/1721) Đang tải: HEM...
#   -> Lỗi khi tải HEM: RetryError[<Future at 0x22492589d10 state=finished raised ValueError>]
# (1143/1721) Đang tải: HEJ...
# (1144/1721) Đang tải: HEC...
# (1145/1721) Đang tải: HDW...
# (1146/1721) Đang tải: HDS...
#   -> Lỗi khi tải HDS: RetryError[<Future at 0x2249256d910 state=finished raised ValueError>]
# (1147/1721) Đang tải: HDP...
# (1148/1721) Đang tải: HDO...
#   -> Lỗi khi tải HDO: RetryError[<Future at 0x224924e96d0 state=finished raised ValueError>]
# (1149/1721) Đang tải: HDM...
# (1150/1721) Đang tải: HDG...
# (1151/1721) Đang tải: HDC...
# (1152/1721) Đang tải: HDB...
# (1153/1721) Đang tải: HDA...
# (1154/1721) Đang tải: HD8...
# (1155/1721) Đang tải: HD6...
# (1156/1721) Đang tải: HD2...
# (1157/1721) Đang tải: HCT...
# (1158/1721) Đang tải: HCM...
# (1159/1721) Đang tải: HCI...
#   -> Lỗi khi tải HCI: RetryError[<Future at 0x22490707f10 state=finished raised ValueError>]
# (1160/1721) Đang tải: HCD...
# (1161/1721) Đang tải: HCC...
# (1162/1721) Đang tải: HCB...
# (1163/1721) Đang tải: HC3...
# (1164/1721) Đang tải: HC1...
# (1165/1721) Đang tải: HBS...
# (1166/1721) Đang tải: HBH...
# (1167/1721) Đang tải: HBD...
# (1168/1721) Đang tải: HBC...
# (1169/1721) Đang tải: HAX...
# (1170/1721) Đang tải: HAW...
#   -> Lỗi khi tải HAW: RetryError[<Future at 0x2249256f2d0 state=finished raised ValueError>]
# (1171/1721) Đang tải: HAV...
# (1172/1721) Đang tải: HAT...
# (1173/1721) Đang tải: HAS...
# (1174/1721) Đang tải: HAR...
# (1175/1721) Đang tải: HAP...
# (1176/1721) Đang tải: HAN...
# (1177/1721) Đang tải: HAM...
# (1178/1721) Đang tải: HAI...
#   -> Lỗi khi tải HAI: RetryError[<Future at 0x22490af5a90 state=finished raised ValueError>]
# (1179/1721) Đang tải: HAH...
# (1180/1721) Đang tải: HAG...
# (1181/1721) Đang tải: HAF...
# (1182/1721) Đang tải: HAD...
# (1183/1721) Đang tải: HAC...
# (1184/1721) Đang tải: HAB...
#   -> Lỗi khi tải HAB: RetryError[<Future at 0x22490b1e290 state=finished raised ValueError>]
# (1185/1721) Đang tải: H11...
# (1186/1721) Đang tải: GVT...
# (1187/1721) Đang tải: GVR...
# (1188/1721) Đang tải: GTT...
#   -> Lỗi khi tải GTT: RetryError[<Future at 0x22492510a90 state=finished raised ValueError>]
# (1189/1721) Đang tải: GTS...
# (1190/1721) Đang tải: GTK...
#   -> Lỗi khi tải GTK: RetryError[<Future at 0x224924e4dd0 state=finished raised ValueError>]
# (1191/1721) Đang tải: GTH...
#   -> Lỗi khi tải GTH: RetryError[<Future at 0x224924f2b10 state=finished raised ValueError>]
# (1192/1721) Đang tải: GTD...
# (1193/1721) Đang tải: GTA...
# (1194/1721) Đang tải: GSP...
# (1195/1721) Đang tải: GSM...
# (1196/1721) Đang tải: GQN...
#   -> Lỗi khi tải GQN: RetryError[<Future at 0x22490d71310 state=finished raised ValueError>]
# (1197/1721) Đang tải: GPC...
# (1198/1721) Đang tải: GND...
# (1199/1721) Đang tải: GMX...
# (1200/1721) Đang tải: GMH...
# (1201/1721) Đang tải: GMD...
# (1202/1721) Đang tải: GMC...
# (1203/1721) Đang tải: GMA...
# (1204/1721) Đang tải: GLW...
# (1205/1721) Đang tải: GLT...
# (1206/1721) Đang tải: GLC...
# (1207/1721) Đang tải: GKM...
# (1208/1721) Đang tải: GIL...
# (1209/1721) Đang tải: GIC...
# (1210/1721) Đang tải: GHC...
# (1211/1721) Đang tải: GH3...
# (1212/1721) Đang tải: GGG...
# (1213/1721) Đang tải: GEX...
# (1214/1721) Đang tải: GER...
# ...
# (1375/1721) Đang tải: DHB...
# (1376/1721) Đang tải: DHA...
# (1377/1721) Đang tải: DGW...
# (1378/1721) Đang tải: DGT...
# (1379/1721) Đang tải: DGC...
# (1380/1721) Đang tải: DFF...
# (1381/1721) Đang tải: DFC...
# (1382/1721) Đang tải: DDV...
# (1383/1721) Đang tải: DDN...
# (1384/1721) Đang tải: DDM...
# (1385/1721) Đang tải: DDH...
# (1386/1721) Đang tải: DDG...
# (1387/1721) Đang tải: DDB...
# (1388/1721) Đang tải: DCT...
# (1389/1721) Đang tải: DCS...
# (1390/1721) Đang tải: DCR...
# (1391/1721) Đang tải: DCM...
# (1392/1721) Đang tải: DCL...
# (1393/1721) Đang tải: DCH...
# (1394/1721) Đang tải: DCG...
# (1395/1721) Đang tải: DCF...
# (1396/1721) Đang tải: DC4...
# (1397/1721) Đang tải: DC2...
# (1398/1721) Đang tải: DC1...
# (1399/1721) Đang tải: DBW...
#   -> Lỗi khi tải DBW: RetryError[<Future at 0x22490fd1c10 state=finished raised ValueError>]
# (1400/1721) Đang tải: DBT...
# (1401/1721) Đang tải: DBM...
# (1402/1721) Đang tải: DBH...
#   -> Lỗi khi tải DBH: RetryError[<Future at 0x22490d7cc90 state=finished raised ValueError>]
# (1403/1721) Đang tải: DBD...
# (1404/1721) Đang tải: DBC...
# (1405/1721) Đang tải: DAT...
# (1406/1721) Đang tải: DAS...
# (1407/1721) Đang tải: DAR...
#   -> Lỗi khi tải DAR: RetryError[<Future at 0x22491078f50 state=finished raised ValueError>]
# (1408/1721) Đang tải: DAN...
# (1409/1721) Đang tải: DAH...
# (1410/1721) Đang tải: DAG...
#   -> Lỗi khi tải DAG: RetryError[<Future at 0x22490f69290 state=finished raised ValueError>]
# (1411/1721) Đang tải: DAE...
# (1412/1721) Đang tải: DAD...
# (1413/1721) Đang tải: DAC...
# (1414/1721) Đang tải: D2D...
# (1415/1721) Đang tải: D17...
#   -> Lỗi khi tải D17: RetryError[<Future at 0x2249139aad0 state=finished raised ValueError>]
# (1416/1721) Đang tải: D11...
# (1417/1721) Đang tải: CYC...
# (1418/1721) Đang tải: CX8...
# (1419/1721) Đang tải: CVT...
# (1420/1721) Đang tải: CVP...
#   -> Lỗi khi tải CVP: RetryError[<Future at 0x22491078a50 state=finished raised ValueError>]
# (1421/1721) Đang tải: CVN...
# (1422/1721) Đang tải: CTX...
# (1423/1721) Đang tải: CTW...
# (1424/1721) Đang tải: CTT...
# (1425/1721) Đang tải: CTS...
# (1426/1721) Đang tải: CTR...
# (1427/1721) Đang tải: CTP...
# (1428/1721) Đang tải: CTN...
#   -> Lỗi khi tải CTN: RetryError[<Future at 0x22490eee590 state=finished raised ValueError>]
# (1429/1721) Đang tải: CTI...
# (1430/1721) Đang tải: CTG...
# (1431/1721) Đang tải: CTF...
# (1432/1721) Đang tải: CTD...
# (1433/1721) Đang tải: CTC...
#   -> Lỗi khi tải CTC: RetryError[<Future at 0x224913abf90 state=finished raised ValueError>]
# (1434/1721) Đang tải: CTB...
# (1435/1721) Đang tải: CTA...
#   -> Lỗi khi tải CTA: RetryError[<Future at 0x22491398250 state=finished raised ValueError>]
# (1436/1721) Đang tải: CT6...
# (1437/1721) Đang tải: CT5...
#   -> Lỗi khi tải CT5: RetryError[<Future at 0x224911d0fd0 state=finished raised ValueError>]
# (1438/1721) Đang tải: CT3...
# (1439/1721) Đang tải: CSV...
# (1440/1721) Đang tải: CST...
# (1441/1721) Đang tải: CSM...
# (1442/1721) Đang tải: CSI...
# (1443/1721) Đang tải: CSC...
# (1444/1721) Đang tải: CRV...
# (1445/1721) Đang tải: CRE...
# (1446/1721) Đang tải: CRC...
# (1447/1721) Đang tải: CQT...
# (1448/1721) Đang tải: CQN...
# (1449/1721) Đang tải: CPI...
# (1450/1721) Đang tải: CPH...
#   -> Lỗi khi tải CPH: RetryError[<Future at 0x224913d2710 state=finished raised ValueError>]
# (1451/1721) Đang tải: CPC...
# (1452/1721) Đang tải: CPA...
# (1453/1721) Đang tải: COM...
# (1454/1721) Đang tải: CNT...
# (1455/1721) Đang tải: CNN...
# (1456/1721) Đang tải: CNG...
# (1457/1721) Đang tải: CNC...
# (1458/1721) Đang tải: CNA...
#   -> Lỗi khi tải CNA: RetryError[<Future at 0x2249143f550 state=finished raised ValueError>]
# (1459/1721) Đang tải: CMX...
# (1460/1721) Đang tải: CMW...
# (1461/1721) Đang tải: CMV...
# (1462/1721) Đang tải: CMT...
# (1463/1721) Đang tải: CMS...
# (1464/1721) Đang tải: CMP...
#   -> Lỗi khi tải CMP: RetryError[<Future at 0x22491001350 state=finished raised ValueError>]
# (1465/1721) Đang tải: CMN...
# (1466/1721) Đang tải: CMM...
# (1467/1721) Đang tải: CMK...
# (1468/1721) Đang tải: CMI...
# (1469/1721) Đang tải: CMG...
# (1470/1721) Đang tải: CMF...
# (1471/1721) Đang tải: CMD...
# (1472/1721) Đang tải: CMC...
# (1473/1721) Đang tải: CLX...
# (1474/1721) Đang tải: CLW...
# (1475/1721) Đang tải: CLM...
# (1476/1721) Đang tải: CLL...
# (1477/1721) Đang tải: CLH...
# (1478/1721) Đang tải: CLG...
#   -> Lỗi khi tải CLG: RetryError[<Future at 0x22491453510 state=finished raised ValueError>]
# (1479/1721) Đang tải: CLC...
# (1480/1721) Đang tải: CKV...
# (1481/1721) Đang tải: CKG...
# (1482/1721) Đang tải: CKD...
# (1483/1721) Đang tải: CKA...
# (1484/1721) Đang tải: CK8...
#   -> Lỗi khi tải CK8: RetryError[<Future at 0x22490f8e710 state=finished raised ValueError>]
# (1485/1721) Đang tải: CJC...
# (1486/1721) Đang tải: CIP...
# (1487/1721) Đang tải: CII...
# (1488/1721) Đang tải: CIG...
# (1489/1721) Đang tải: CID...
# (1490/1721) Đang tải: CIA...
# (1491/1721) Đang tải: CI5...
# (1492/1721) Đang tải: CHS...
# (1493/1721) Đang tải: CHP...
# (1494/1721) Đang tải: CHC...
# (1495/1721) Đang tải: CH5...
# (1496/1721) Đang tải: CGV...
# (1497/1721) Đang tải: CGL...
#   -> Lỗi khi tải CGL: RetryError[<Future at 0x2248ef83e10 state=finished raised ValueError>]
# (1498/1721) Đang tải: CFV...
# (1499/1721) Đang tải: CFM...
# (1500/1721) Đang tải: CET...
# (1501/1721) Đang tải: CEO...
# (1502/1721) Đang tải: CEN...
# (1503/1721) Đang tải: CEG...
# (1504/1721) Đang tải: CEE...
#   -> Lỗi khi tải CEE: RetryError[<Future at 0x22490f37910 state=finished raised ValueError>]
# (1505/1721) Đang tải: CE1...
#   -> Lỗi khi tải CE1: RetryError[<Future at 0x22491014c10 state=finished raised ValueError>]
# (1506/1721) Đang tải: CDR...
# (1507/1721) Đang tải: CDP...
# (1508/1721) Đang tải: CDO...
# (1509/1721) Đang tải: CDN...
# (1510/1721) Đang tải: CDH...
# (1511/1721) Đang tải: CDG...
# (1512/1721) Đang tải: CDC...
# (1513/1721) Đang tải: CCV...
# (1514/1721) Đang tải: CCT...
# (1515/1721) Đang tải: CCR...
# (1516/1721) Đang tải: CCP...
# (1517/1721) Đang tải: CCM...
# (1518/1721) Đang tải: CCL...
# (1519/1721) Đang tải: CCI...
# (1520/1721) Đang tải: CCC...
# (1521/1721) Đang tải: CCA...
# (1522/1721) Đang tải: CC4...
# (1523/1721) Đang tải: CC1...
# (1524/1721) Đang tải: CBS...
# (1525/1721) Đang tải: CBI...
# (1526/1721) Đang tải: CAV...
#   -> Lỗi khi tải CAV: RetryError[<Future at 0x224913d3f50 state=finished raised ValueError>]
# (1527/1721) Đang tải: CAT...
# (1528/1721) Đang tải: CAR...
# (1529/1721) Đang tải: CAP...
# (1530/1721) Đang tải: CAN...
# (1531/1721) Đang tải: CAG...
# (1532/1721) Đang tải: CAD...
# (1533/1721) Đang tải: CAB...
#   -> Lỗi khi tải CAB: RetryError[<Future at 0x224914d7d90 state=finished raised ValueError>]
# (1534/1721) Đang tải: C92...
# (1535/1721) Đang tải: C69...
# (1536/1721) Đang tải: C4G...
# (1537/1721) Đang tải: C47...
# (1538/1721) Đang tải: C32...
# (1539/1721) Đang tải: C22...
# (1540/1721) Đang tải: C21...
# (1541/1721) Đang tải: C12...
#   -> Lỗi khi tải C12: RetryError[<Future at 0x224914d56d0 state=finished raised ValueError>]
# (1542/1721) Đang tải: BXT...
#   -> Lỗi khi tải BXT: RetryError[<Future at 0x22490f69f10 state=finished raised ValueError>]
# (1543/1721) Đang tải: BXH...
# (1544/1721) Đang tải: BWS...
# (1545/1721) Đang tải: BWE...
# (1546/1721) Đang tải: BWA...
# (1547/1721) Đang tải: BVS...
# (1548/1721) Đang tải: BVN...
# (1549/1721) Đang tải: BVL...
# (1550/1721) Đang tải: BVH...
# (1551/1721) Đang tải: BVG...
# (1552/1721) Đang tải: BVB...
# (1553/1721) Đang tải: BUD...
#   -> Lỗi khi tải BUD: RetryError[<Future at 0x224914feb10 state=finished raised ValueError>]
# (1554/1721) Đang tải: BTW...
# (1555/1721) Đang tải: BTV...
# (1556/1721) Đang tải: BTU...
# (1557/1721) Đang tải: BTT...
# (1558/1721) Đang tải: BTS...
# (1559/1721) Đang tải: BTP...
# (1560/1721) Đang tải: BTN...
# (1561/1721) Đang tải: BTH...
# (1562/1721) Đang tải: BTG...
# (1563/1721) Đang tải: BTD...
# (1564/1721) Đang tải: BTB...
# (1565/1721) Đang tải: BT6...
#   -> Lỗi khi tải BT6: RetryError[<Future at 0x224925ad9d0 state=finished raised ValueError>]
# (1566/1721) Đang tải: BT1...
# (1567/1721) Đang tải: BST...
# (1568/1721) Đang tải: BSR...
# (1569/1721) Đang tải: BSQ...
# (1570/1721) Đang tải: BSP...
# (1571/1721) Đang tải: BSL...
# (1572/1721) Đang tải: BSI...
# (1573/1721) Đang tải: BSH...
# (1574/1721) Đang tải: BSG...
# (1575/1721) Đang tải: BSD...
# (1576/1721) Đang tải: BSC...
# (1577/1721) Đang tải: BSA...
# (1578/1721) Đang tải: BRS...
# (1579/1721) Đang tải: BRR...
# (1580/1721) Đang tải: BRC...
# (1581/1721) Đang tải: BQB...
# (1582/1721) Đang tải: BPW...
#   -> Lỗi khi tải BPW: RetryError[<Future at 0x2249154d410 state=finished raised ValueError>]
# (1583/1721) Đang tải: BPC...
# (1584/1721) Đang tải: BOT...
# (1585/1721) Đang tải: BNW...
# (1586/1721) Đang tải: BNA...
# (1587/1721) Đang tải: BMV...
# (1588/1721) Đang tải: BMS...
# (1589/1721) Đang tải: BMP...
# (1590/1721) Đang tải: BMN...
# (1591/1721) Đang tải: BMK...
# (1592/1721) Đang tải: BMJ...
# (1593/1721) Đang tải: BMI...
# (1594/1721) Đang tải: BMG...
# (1595/1721) Đang tải: BMF...
# (1596/1721) Đang tải: BMD...
# (1597/1721) Đang tải: BMC...
# (1598/1721) Đang tải: BLW...
#   -> Lỗi khi tải BLW: RetryError[<Future at 0x224914bd5d0 state=finished raised ValueError>]
# (1599/1721) Đang tải: BLU...
#   -> Lỗi khi tải BLU: RetryError[<Future at 0x22491579350 state=finished raised ValueError>]
# (1600/1721) Đang tải: BLT...
# (1601/1721) Đang tải: BLN...
# (1602/1721) Đang tải: BLI...
# (1603/1721) Đang tải: BLF...
# (1604/1721) Đang tải: BKH...
#   -> Lỗi khi tải BKH: RetryError[<Future at 0x224915d1410 state=finished raised ValueError>]
# (1605/1721) Đang tải: BKG...
# (1606/1721) Đang tải: BKC...
# (1607/1721) Đang tải: BIO...
# (1608/1721) Đang tải: BII...
# (1609/1721) Đang tải: BIG...
# (1610/1721) Đang tải: BID...
# (1611/1721) Đang tải: BIC...
# (1612/1721) Đang tải: BHT...
#   -> Lỗi khi tải BHT: RetryError[<Future at 0x224914b1f10 state=finished raised ValueError>]
# (1613/1721) Đang tải: BHP...
# (1614/1721) Đang tải: BHN...
# (1615/1721) Đang tải: BHK...
# (1616/1721) Đang tải: BHI...
# (1617/1721) Đang tải: BHH...
# (1618/1721) Đang tải: BHG...
#   -> Lỗi khi tải BHG: RetryError[<Future at 0x2249107b0d0 state=finished raised ValueError>]
# (1619/1721) Đang tải: BHC...
# (1620/1721) Đang tải: BHA...
# (1621/1721) Đang tải: BGW...
# (1622/1721) Đang tải: BGE...
# (1623/1721) Đang tải: BFC...
# (1624/1721) Đang tải: BEL...
# (1625/1721) Đang tải: BED...
# (1626/1721) Đang tải: BDW...
# (1627/1721) Đang tải: BDT...
# (1628/1721) Đang tải: BDG...
# (1629/1721) Đang tải: BDB...
# (1630/1721) Đang tải: BCV...
#   -> Lỗi khi tải BCV: RetryError[<Future at 0x224915b9610 state=finished raised ValueError>]
# (1631/1721) Đang tải: BCR...
# (1632/1721) Đang tải: BCP...
# (1633/1721) Đang tải: BCO...
#   -> Lỗi khi tải BCO: RetryError[<Future at 0x2249150bc50 state=finished raised ValueError>]
# (1634/1721) Đang tải: BCM...
# (1635/1721) Đang tải: BCG...
# (1636/1721) Đang tải: BCF...
# (1637/1721) Đang tải: BCE...
# (1638/1721) Đang tải: BCC...
# (1639/1721) Đang tải: BCB...
# (1640/1721) Đang tải: BCA...
# (1641/1721) Đang tải: BBT...
# (1642/1721) Đang tải: BBS...
# (1643/1721) Đang tải: BBM...
# (1644/1721) Đang tải: BBH...
# (1645/1721) Đang tải: BBC...
# (1646/1721) Đang tải: BAX...
# (1647/1721) Đang tải: BAL...
# (1648/1721) Đang tải: BAF...
# (1649/1721) Đang tải: BAB...
# (1650/1721) Đang tải: B82...
#   -> Lỗi khi tải B82: RetryError[<Future at 0x224915fb450 state=finished raised ValueError>]
# (1651/1721) Đang tải: AVG...
# (1652/1721) Đang tải: AVF...
#   -> Lỗi khi tải AVF: RetryError[<Future at 0x22491418c90 state=finished raised ValueError>]
# (1653/1721) Đang tải: AVC...
# (1654/1721) Đang tải: AUM...
#   -> Lỗi khi tải AUM: RetryError[<Future at 0x22491048410 state=finished raised ValueError>]
# (1655/1721) Đang tải: ATS...
# (1656/1721) Đang tải: ATG...
# (1657/1721) Đang tải: ATB...
# (1658/1721) Đang tải: ATA...
# (1659/1721) Đang tải: AST...
# (1660/1721) Đang tải: ASP...
# (1661/1721) Đang tải: ASM...
# (1662/1721) Đang tải: ASG...
# (1663/1721) Đang tải: ASA...
#   -> Lỗi khi tải ASA: RetryError[<Future at 0x2249167a790 state=finished raised ValueError>]
# (1664/1721) Đang tải: ART...
#   -> Lỗi khi tải ART: RetryError[<Future at 0x224915caf10 state=finished raised ValueError>]
# (1665/1721) Đang tải: ARM...
# (1666/1721) Đang tải: APT...
# (1667/1721) Đang tải: APS...
# (1668/1721) Đang tải: APP...
# (1669/1721) Đang tải: APL...
# (1670/1721) Đang tải: API...
# (1671/1721) Đang tải: APH...
# (1672/1721) Đang tải: APG...
# (1673/1721) Đang tải: APF...
# (1674/1721) Đang tải: APC...
# (1675/1721) Đang tải: ANV...
# (1676/1721) Đang tải: ANT...
# (1677/1721) Đang tải: AMV...
# (1678/1721) Đang tải: AMS...
# (1679/1721) Đang tải: AMP...
# (1680/1721) Đang tải: AME...
# (1681/1721) Đang tải: AMD...
#   -> Lỗi khi tải AMD: RetryError[<Future at 0x22491629d90 state=finished raised ValueError>]
# (1682/1721) Đang tải: AMC...
# (1683/1721) Đang tải: ALV...
# (1684/1721) Đang tải: ALT...
# (1685/1721) Đang tải: AIG...
# (1686/1721) Đang tải: AIC...
# (1687/1721) Đang tải: AGX...
# (1688/1721) Đang tải: AGR...
# (1689/1721) Đang tải: AGP...
# (1690/1721) Đang tải: AGM...
# (1691/1721) Đang tải: AGG...
# (1692/1721) Đang tải: AGF...
# (1693/1721) Đang tải: AGE...
#   -> Lỗi khi tải AGE: RetryError[<Future at 0x224913b94d0 state=finished raised ValueError>]
# (1694/1721) Đang tải: AG1...
# (1695/1721) Đang tải: AFX...
# (1696/1721) Đang tải: ADS...
# (1697/1721) Đang tải: ADP...
# (1698/1721) Đang tải: ADG...
# (1699/1721) Đang tải: ADC...
# (1700/1721) Đang tải: ACV...
# (1701/1721) Đang tải: ACS...
# (1702/1721) Đang tải: ACM...
# (1703/1721) Đang tải: ACL...
# (1704/1721) Đang tải: ACG...
# (1705/1721) Đang tải: ACE...
# (1706/1721) Đang tải: ACC...
# (1707/1721) Đang tải: ACB...
# (1708/1721) Đang tải: ABW...
# (1709/1721) Đang tải: ABT...
# (1710/1721) Đang tải: ABS...
# (1711/1721) Đang tải: ABR...
# (1712/1721) Đang tải: ABI...
# (1713/1721) Đang tải: ABC...
# (1714/1721) Đang tải: ABB...
# (1715/1721) Đang tải: AAV...
# (1716/1721) Đang tải: AAT...
# (1717/1721) Đang tải: AAS...
# (1718/1721) Đang tải: AAM...
# (1719/1721) Đang tải: AAH...
# (1720/1721) Đang tải: AAA...
# (1721/1721) Đang tải: A32...
#
# Đang tổng hợp dữ liệu...
# --- HOÀN TẤT ---
# DataFrame tổng (5 dòng đầu):
#         time   open   high    low  close  volume ticker
# 0 2025-01-02  39.75  39.75  39.75  39.75       0    YTC
# 1 2025-01-03  33.89  33.89  33.89  33.89     400    YTC
# 2 2025-01-06  33.89  34.09  33.89  33.99     502    YTC
# 3 2025-01-07  33.99  33.99  33.99  33.99       0    YTC
# 4 2025-01-08  33.99  33.99  33.99  33.99       0    YTC
#
# DataFrame tổng (5 dòng cuối):
#              time  open  high   low  close  volume ticker
# 226451 2025-10-08  36.6  36.6  36.6   36.6     100    A32
# 226452 2025-10-10  31.2  36.3  31.2   36.3    1700    A32
# 226453 2025-10-14  35.8  35.8  34.6   34.7    3100    A32
# 226454 2025-10-15  34.0  34.0  33.4   33.5    3300    A32
# 226455 2025-10-16  33.6  33.6  33.6   33.6     100    A32
#
# Các mã không có dữ liệu hoặc bị lỗi: 208
# ['XDC', 'X77', 'VXP', 'VTM', 'VSP', 'VMI', 'VLP', 'VKP', 'VKD', 'VIS', 'VHI', 'VE4', 'VDM', 'VDB', 'VCE', 'VAT', 'V15', 'UTT', 'TVW', 'TVP', 'TTZ', 'TTB', 'TS5', 'TS4', 'TNM', 'TNA', 'TKG', 'TKC', 'THI', 'TGG', 'TEC', 'TDN', 'TDI', 'TC6', 'TBT', 'TBH', 'TAP', 'TAG', 'TAC', 'TA3', 'T12', 'SVL', 'SVH', 'STL', 'SSU', 'SSF', 'SRT', 'SPP', 'SPA', 'SON', 'SJF', 'SJC', 'SIC', 'SHX', 'SGO', 'SDX', 'SDJ', 'SDH', 'SDB', 'SD8', 'SD1', 'SCV', 'SCA', 'S96', 'S27', 'ROS', 'RGC', 'RDP', 'QLT', 'QLD', 'PYU', 'PXC', 'PX1', 'PVA', 'PTN', 'PSG', 'PQN', 'PPI', 'PID', 'PDT', 'PCN', 'NTB', 'NSS', 'NS3', 'NNQ', 'NNG', 'NHP', 'NDF', 'MXC', 'MTB', 'MPY', 'MIM', 'MHL', 'MES', 'MEG', 'MCI', 'MCD', 'MC3', 'MBN', 'LYF', 'LWS', 'LCW', 'LBC', 'KTW', 'KTT', 'KSH', 'KLM', 'KLF', 'KHL', 'KHB', 'KHA', 'KAC', 'ITA', 'IPH', 'IBN', 'IBC', 'HVG', 'HUX', 'HTW', 'HTR', 'HTK', 'HTH', 'HSA', 'HRT', 'HNT', 'HNR', 'HNE', 'HLT', 'HLR', 'HLG', 'HLE', 'HLA', 'HKP', 'HHR', 'HGW', 'HGR', 'HGC', 'HGA', 'HEM', 'HDS', 'HDO', 'HCI', 'HAW', 'HAI', 'HAB', 'GTT', 'GTK', 'GTH', 'GQN', 'GE2', 'GAB', 'FTI', 'FLC', 'FDG', 'FBC', 'FBA', 'EMC', 'EAD', 'DZM', 'DX2', 'DTV', 'DT4', 'DSV', 'DPS', 'DPD', 'DNB', 'DLM', 'DLD', 'DKH', 'DBW', 'DBH', 'DAR', 'DAG', 'D17', 'CVP', 'CTN', 'CTC', 'CTA', 'CT5', 'CPH', 'CNA', 'CMP', 'CLG', 'CK8', 'CGL', 'CEE', 'CE1', 'CAV', 'CAB', 'C12', 'BXT', 'BUD', 'BT6', 'BPW', 'BLW', 'BLU', 'BKH', 'BHT', 'BHG', 'BCV', 'BCO', 'B82', 'AVF', 'AUM', 'ASA', 'ART', 'AMD', 'AGE']

# %%
df_tong.to_csv('./data/vnstock/vnstock_1d.csv', index=False, encoding='utf-8-sig')
